# %%
import io
import itertools

import numpy as np
import sklearn.metrics

import tensorflow as tf
from tensorboard.plugins.hparams import api as hp

import matplotlib.pyplot as plt

# %%
data_train = np.load(r"datasets/Trousers & Jeans - All - Train.npz")
data_val = np.load(r"datasets/Trousers & Jeans - All - Validation.npz")
data_test = np.load(r"datasets/Trousers & Jeans - All - Test.npz")

# %%
images_train = data_train['images']
labels_train = data_train['labels']

images_val = data_val['images']
labels_val = data_val['labels']

images_test = data_test['images']
labels_test = data_test['labels']

# %%
images_train = images_train/255.0
images_val = images_val/255.0
images_test = images_test/255.0

# %%
# Defining the hypermatarest we would test and their range
HP_LAMBDA_REG = hp.HParam('lambda', hp.Discrete([0.0, 1e-5, 5e-5, 1e-4, 5e-4, 1e-3, 5e-3, 1e-2, 5e-2, 0.1]))

METRIC_ACCURACY = 'accuracy'

# Logging setup info
with tf.summary.create_file_writer(r'D:/sam/Logs/Model 2/hparam_tuning/').as_default():
    hp.hparams_config(
        hparams=[HP_LAMBDA_REG],
        metrics=[hp.Metric(METRIC_ACCURACY, display_name='Accuracy')],
    )

# %%
EPOCHS = 20
BATCH_SIZE = 64

# %%
# Wrapping our model and training in a function
def train_test_model(hparams, session_num):
    
    # Outlining the model/architecture of our CNN
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(64, 3, activation='relu', input_shape=(120,90,3), kernel_regularizer=tf.keras.regularizers.l2(hparams[HP_LAMBDA_REG])),
        tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
        tf.keras.layers.Conv2D(64, 3, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(hparams[HP_LAMBDA_REG])),
        tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(hparams[HP_LAMBDA_REG])),
        tf.keras.layers.Dense(4)
    ])
    
    # Defining the loss function
    loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

    # Compiling the model with parameter value for the optimizer
    model.compile(optimizer='adam', loss=loss_fn, metrics=['accuracy', tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, name='sparse_categorical_crossentropy')])
    
    def plot_confusion_matrix(cm, class_names):
        """
        Returns a matplotlib figure containing the plotted confusion matrix.

        Args:
          cm (array, shape = [n, n]): a confusion matrix of integer classes
          class_names (array, shape = [n]): String names of the integer classes
        """
        figure = plt.figure(figsize=(8, 8))
        plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
        plt.title("Confusion matrix")
        plt.colorbar()
        tick_marks = np.arange(len(class_names))
        plt.xticks(tick_marks, class_names, rotation=45)
        plt.yticks(tick_marks, class_names)

        # Normalize the confusion matrix.
        cm = np.around(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], decimals=2)

        # Use white text if squares are dark; otherwise black.
        threshold = cm.max() / 2.
        for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            color = "white" if cm[i, j] > threshold else "black"
            plt.text(j, i, cm[i, j], horizontalalignment="center", color=color)

        plt.tight_layout()
        plt.ylabel('True label')
        plt.xlabel('Predicted label')
        return figure
    
    
    # Logging the training process data to use later in tensorboard
    log_dir = "D:/sam/Logs/Model 2/fit/" + "run-{}".format(session_num)
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, profile_batch=0)
    file_writer_cm = tf.summary.create_file_writer(log_dir + '/cm')  
    
    
    def plot_to_image(figure):
        """Converts the matplotlib plot specified by 'figure' to a PNG image and
        returns it. The supplied figure is closed and inaccessible after this call."""
        # Save the plot to a PNG in memory.
        buf = io.BytesIO()
        plt.savefig(buf, format='png')
        # Closing the figure prevents it from being displayed directly inside
        # the notebook.
        plt.close(figure)
        buf.seek(0)
        # Convert PNG buffer to TF image
        image = tf.image.decode_png(buf.getvalue(), channels=4)
        # Add the batch dimension
        image = tf.expand_dims(image, 0)
        return image
    
    def log_confusion_matrix(epoch, logs):
        # Use the model to predict the values from the validation dataset.
        test_pred_raw = model.predict(images_val)
        test_pred = np.argmax(test_pred_raw, axis=1)

        # Calculate the confusion matrix.
        cm = sklearn.metrics.confusion_matrix(labels_val, test_pred)
        # Log the confusion matrix as an image summary.
        figure = plot_confusion_matrix(cm, class_names=['Trousers Male', 'Jenas Male', 'Trousers Female', 'Jeans Female'])
        cm_image = plot_to_image(figure)

        # Log the confusion matrix as an image summary.
        with file_writer_cm.as_default():
            tf.summary.image("Confusion Matrix", cm_image, step=epoch)
    
    
    # Define the per-epoch callback.
    cm_callback = tf.keras.callbacks.LambdaCallback(on_epoch_end=log_confusion_matrix)

    
    # Defining early stopping to prevent overfitting
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor = 'val_sparse_categorical_crossentropy',
        mode = 'auto',
        min_delta = 0,
        patience = 2,
        verbose = 0, 
        restore_best_weights = True
    )
    
    # Training the model
    model.fit(
        images_train,
        labels_train,
        epochs = EPOCHS,
        batch_size = BATCH_SIZE,
        callbacks = [tensorboard_callback, cm_callback, early_stopping],
        validation_data = (images_val,labels_val),
        verbose = 2
    )
    
    _, accuracy, _ = model.evaluate(images_val,labels_val)
    
    model.save(r"D:/sam/Logs/Model 2/Run-{}".format(session_num))
    
    return accuracy

# %%
# Creating a function to log the resuls
def run(log_dir, hparams, session_num):
    
    with tf.summary.create_file_writer(log_dir).as_default():
        hp.hparams(hparams)  # record the values used in this trial
        accuracy = train_test_model(hparams, session_num)
        tf.summary.scalar(METRIC_ACCURACY, accuracy, step=1)

# %%
session_num = 1

for lambda_reg in HP_LAMBDA_REG.domain.values:

    hparams = {
        HP_LAMBDA_REG: lambda_reg
    }
                    
    run_name = "run-%d" % session_num
    print('--- Starting trial: %s' % run_name)
    print({h.name: hparams[h] for h in hparams})
    run('D:/sam/Logs/Model 2/hparam_tuning/' + run_name, hparams, session_num)

    session_num += 1
# Out:
# --- Starting trial: run-1
# {'lambda': 0.0}
# Epoch 1/20
# 63/63 - 49s - loss: 1.2743 - accuracy: 0.5180 - sparse_categorical_crossentropy: 1.2713 - val_loss: 0.9768 - val_accuracy: 0.5880 - val_sparse_categorical_crossentropy: 0.9776
# Epoch 2/20
# 63/63 - 47s - loss: 0.8401 - accuracy: 0.6501 - sparse_categorical_crossentropy: 0.8392 - val_loss: 0.8720 - val_accuracy: 0.6360 - val_sparse_categorical_crossentropy: 0.8746
# Epoch 3/20
# 63/63 - 45s - loss: 0.7415 - accuracy: 0.7023 - sparse_categorical_crossentropy: 0.7424 - val_loss: 0.8666 - val_accuracy: 0.6480 - val_sparse_categorical_crossentropy: 0.8668
# Epoch 4/20
# 63/63 - 45s - loss: 0.6641 - accuracy: 0.7378 - sparse_categorical_crossentropy: 0.6645 - val_loss: 0.8758 - val_accuracy: 0.6520 - val_sparse_categorical_crossentropy: 0.8763
# Epoch 5/20
# 63/63 - 46s - loss: 0.6205 - accuracy: 0.7440 - sparse_categorical_crossentropy: 0.6207 - val_loss: 0.7691 - val_accuracy: 0.6900 - val_sparse_categorical_crossentropy: 0.7709
# Epoch 6/20
# 63/63 - 47s - loss: 0.5411 - accuracy: 0.7860 - sparse_categorical_crossentropy: 0.5410 - val_loss: 0.7435 - val_accuracy: 0.7200 - val_sparse_categorical_crossentropy: 0.7464
# Epoch 7/20
# 63/63 - 46s - loss: 0.4914 - accuracy: 0.8144 - sparse_categorical_crossentropy: 0.4933 - val_loss: 0.6845 - val_accuracy: 0.7400 - val_sparse_categorical_crossentropy: 0.6851
# Epoch 8/20
# 63/63 - 47s - loss: 0.4316 - accuracy: 0.8329 - sparse_categorical_crossentropy: 0.4313 - val_loss: 0.7018 - val_accuracy: 0.7500 - val_sparse_categorical_crossentropy: 0.7024
# Epoch 9/20
# 63/63 - 46s - loss: 0.3933 - accuracy: 0.8484 - sparse_categorical_crossentropy: 0.3947 - val_loss: 0.7249 - val_accuracy: 0.7240 - val_sparse_categorical_crossentropy: 0.7263
# 16/16 [==============================] - 1s 80ms/step - loss: 0.6845 - accuracy: 0.7400 - sparse_categorical_crossentropy: 0.6958
# INFO:tensorflow:Assets written to: D:/sam/Logs/Model 2/Run-1\assets
# --- Starting trial: run-2
# {'lambda': 1e-05}
# Epoch 1/20
# 63/63 - 52s - loss: 1.4229 - accuracy: 0.5232 - sparse_categorical_crossentropy: 1.4094 - val_loss: 1.0433 - val_accuracy: 0.5540 - val_sparse_categorical_crossentropy: 1.0339
# Epoch 2/20
# 63/63 - 49s - loss: 0.8170 - accuracy: 0.6696 - sparse_categorical_crossentropy: 0.8048 - val_loss: 0.8883 - val_accuracy: 0.6580 - val_sparse_categorical_crossentropy: 0.8776
# Epoch 3/20
# 63/63 - 49s - loss: 0.7032 - accuracy: 0.7258 - sparse_categorical_crossentropy: 0.6924 - val_loss: 0.8542 - val_accuracy: 0.6460 - val_sparse_categorical_crossentropy: 0.8414
# Epoch 4/20
# 63/63 - 48s - loss: 0.6260 - accuracy: 0.7575 - sparse_categorical_crossentropy: 0.6140 - val_loss: 0.7490 - val_accuracy: 0.7060 - val_sparse_categorical_crossentropy: 0.7362
# Epoch 5/20
# 63/63 - 49s - loss: 0.5516 - accuracy: 0.7947 - sparse_categorical_crossentropy: 0.5373 - val_loss: 0.7102 - val_accuracy: 0.7360 - val_sparse_categorical_crossentropy: 0.6966
# Epoch 6/20
# 63/63 - 49s - loss: 0.5099 - accuracy: 0.8022 - sparse_categorical_crossentropy: 0.4962 - val_loss: 0.7825 - val_accuracy: 0.7360 - val_sparse_categorical_crossentropy: 0.7640
# Epoch 7/20
# 63/63 - 48s - loss: 0.4569 - accuracy: 0.8314 - sparse_categorical_crossentropy: 0.4400 - val_loss: 0.7650 - val_accuracy: 0.7520 - val_sparse_categorical_crossentropy: 0.7463
# 16/16 [==============================] - 2s 106ms/step - loss: 0.7102 - accuracy: 0.7360 - sparse_categorical_crossentropy: 0.7074
# INFO:tensorflow:Assets written to: D:/sam/Logs/Model 2/Run-2\assets
# --- Starting trial: run-3
# {'lambda': 5e-05}
# Epoch 1/20
# 63/63 - 52s - loss: 1.5665 - accuracy: 0.4833 - sparse_categorical_crossentropy: 1.5211 - val_loss: 1.0462 - val_accuracy: 0.5760 - val_sparse_categorical_crossentropy: 1.0054
# Epoch 2/20
# 63/63 - 49s - loss: 0.8850 - accuracy: 0.6608 - sparse_categorical_crossentropy: 0.8403 - val_loss: 0.8963 - val_accuracy: 0.6500 - val_sparse_categorical_crossentropy: 0.8524
# Epoch 3/20
# 63/63 - 49s - loss: 0.7607 - accuracy: 0.7110 - sparse_categorical_crossentropy: 0.7143 - val_loss: 0.9075 - val_accuracy: 0.6540 - val_sparse_categorical_crossentropy: 0.8588
# Epoch 4/20
# 63/63 - 49s - loss: 0.6990 - accuracy: 0.7435 - sparse_categorical_crossentropy: 0.6499 - val_loss: 0.8923 - val_accuracy: 0.6480 - val_sparse_categorical_crossentropy: 0.8435
# Epoch 5/20
# 63/63 - 49s - loss: 0.6289 - accuracy: 0.7682 - sparse_categorical_crossentropy: 0.5760 - val_loss: 0.7793 - val_accuracy: 0.7340 - val_sparse_categorical_crossentropy: 0.7277
# Epoch 6/20
# 63/63 - 50s - loss: 0.5813 - accuracy: 0.7972 - sparse_categorical_crossentropy: 0.5258 - val_loss: 0.8687 - val_accuracy: 0.6860 - val_sparse_categorical_crossentropy: 0.8144
# Epoch 7/20
# 63/63 - 48s - loss: 0.5695 - accuracy: 0.7987 - sparse_categorical_crossentropy: 0.5128 - val_loss: 0.8650 - val_accuracy: 0.6700 - val_sparse_categorical_crossentropy: 0.8059
# 16/16 [==============================] - 2s 106ms/step - loss: 0.7793 - accuracy: 0.7340 - sparse_categorical_crossentropy: 0.7365
# INFO:tensorflow:Assets written to: D:/sam/Logs/Model 2/Run-3\assets
# --- Starting trial: run-4
# {'lambda': 0.0001}
# Epoch 1/20
# 63/63 - 54s - loss: 1.4725 - accuracy: 0.4915 - sparse_categorical_crossentropy: 1.3944 - val_loss: 1.0809 - val_accuracy: 0.5960 - val_sparse_categorical_crossentropy: 1.0149
# Epoch 2/20
# 63/63 - 50s - loss: 0.9236 - accuracy: 0.6596 - sparse_categorical_crossentropy: 0.8592 - val_loss: 0.9624 - val_accuracy: 0.6200 - val_sparse_categorical_crossentropy: 0.9001
# Epoch 3/20
# 63/63 - 50s - loss: 0.7917 - accuracy: 0.7018 - sparse_categorical_crossentropy: 0.7299 - val_loss: 1.1338 - val_accuracy: 0.5740 - val_sparse_categorical_crossentropy: 1.0771
# Epoch 4/20
# 63/63 - 49s - loss: 0.7362 - accuracy: 0.7288 - sparse_categorical_crossentropy: 0.6767 - val_loss: 0.7879 - val_accuracy: 0.7260 - val_sparse_categorical_crossentropy: 0.7285
# Epoch 5/20
# 63/63 - 50s - loss: 0.6693 - accuracy: 0.7652 - sparse_categorical_crossentropy: 0.6087 - val_loss: 0.8106 - val_accuracy: 0.6860 - val_sparse_categorical_crossentropy: 0.7511
# Epoch 6/20
# 63/63 - 51s - loss: 0.6526 - accuracy: 0.7647 - sparse_categorical_crossentropy: 0.5907 - val_loss: 0.7612 - val_accuracy: 0.7380 - val_sparse_categorical_crossentropy: 0.6990
# Epoch 7/20
# 63/63 - 52s - loss: 0.6254 - accuracy: 0.7805 - sparse_categorical_crossentropy: 0.5606 - val_loss: 0.7979 - val_accuracy: 0.7140 - val_sparse_categorical_crossentropy: 0.7347
# Epoch 8/20
# 63/63 - 48s - loss: 0.5585 - accuracy: 0.8097 - sparse_categorical_crossentropy: 0.4917 - val_loss: 0.8187 - val_accuracy: 0.7380 - val_sparse_categorical_crossentropy: 0.7530
# 16/16 [==============================] - 2s 105ms/step - loss: 0.7612 - accuracy: 0.7380 - sparse_categorical_crossentropy: 0.7088
# INFO:tensorflow:Assets written to: D:/sam/Logs/Model 2/Run-4\assets
# --- Starting trial: run-5
# {'lambda': 0.0005}
# Epoch 1/20
# 63/63 - 50s - loss: 1.6913 - accuracy: 0.4978 - sparse_categorical_crossentropy: 1.3989 - val_loss: 1.2442 - val_accuracy: 0.6060 - val_sparse_categorical_crossentropy: 1.0065
# Epoch 2/20
# 63/63 - 47s - loss: 1.0791 - accuracy: 0.6491 - sparse_categorical_crossentropy: 0.8733 - val_loss: 1.1524 - val_accuracy: 0.5860 - val_sparse_categorical_crossentropy: 0.9689
# Epoch 3/20
# 63/63 - 48s - loss: 0.9656 - accuracy: 0.6811 - sparse_categorical_crossentropy: 0.7967 - val_loss: 1.1530 - val_accuracy: 0.5680 - val_sparse_categorical_crossentropy: 0.9940
# Epoch 4/20
# 63/63 - 48s - loss: 0.8850 - accuracy: 0.7003 - sparse_categorical_crossentropy: 0.7357 - val_loss: 0.9337 - val_accuracy: 0.6720 - val_sparse_categorical_crossentropy: 0.7947
# Epoch 5/20
# 63/63 - 48s - loss: 0.8312 - accuracy: 0.7233 - sparse_categorical_crossentropy: 0.6963 - val_loss: 1.0418 - val_accuracy: 0.6240 - val_sparse_categorical_crossentropy: 0.9100
# Epoch 6/20
# 63/63 - 48s - loss: 0.8272 - accuracy: 0.7235 - sparse_categorical_crossentropy: 0.6959 - val_loss: 0.9237 - val_accuracy: 0.6540 - val_sparse_categorical_crossentropy: 0.7977
# 16/16 [==============================] - 2s 101ms/step - loss: 0.9337 - accuracy: 0.6720 - sparse_categorical_crossentropy: 0.8000
# INFO:tensorflow:Assets written to: D:/sam/Logs/Model 2/Run-5\assets
# --- Starting trial: run-6
# {'lambda': 0.001}
# Epoch 1/20
# 63/63 - 50s - loss: 1.8427 - accuracy: 0.4765 - sparse_categorical_crossentropy: 1.4100 - val_loss: 1.3543 - val_accuracy: 0.5720 - val_sparse_categorical_crossentropy: 1.0528
# Epoch 2/20
# 63/63 - 48s - loss: 1.1326 - accuracy: 0.6518 - sparse_categorical_crossentropy: 0.8657 - val_loss: 1.2268 - val_accuracy: 0.5680 - val_sparse_categorical_crossentropy: 0.9943
# Epoch 3/20
# 63/63 - 50s - loss: 1.0141 - accuracy: 0.6713 - sparse_categorical_crossentropy: 0.7991 - val_loss: 1.1087 - val_accuracy: 0.6240 - val_sparse_categorical_crossentropy: 0.9091
# Epoch 4/20
# 63/63 - 50s - loss: 0.9284 - accuracy: 0.6913 - sparse_categorical_crossentropy: 0.7403 - val_loss: 1.0061 - val_accuracy: 0.6540 - val_sparse_categorical_crossentropy: 0.8335
# Epoch 5/20
# 63/63 - 49s - loss: 0.8736 - accuracy: 0.7113 - sparse_categorical_crossentropy: 0.7102 - val_loss: 0.9913 - val_accuracy: 0.6360 - val_sparse_categorical_crossentropy: 0.8354
# Epoch 6/20
# 63/63 - 49s - loss: 0.7903 - accuracy: 0.7485 - sparse_categorical_crossentropy: 0.6392 - val_loss: 0.8789 - val_accuracy: 0.6900 - val_sparse_categorical_crossentropy: 0.7291
# Epoch 7/20
# 63/63 - 49s - loss: 0.7596 - accuracy: 0.7617 - sparse_categorical_crossentropy: 0.6088 - val_loss: 0.9161 - val_accuracy: 0.6680 - val_sparse_categorical_crossentropy: 0.7674
# Epoch 8/20
# 63/63 - 49s - loss: 0.7254 - accuracy: 0.7772 - sparse_categorical_crossentropy: 0.5740 - val_loss: 0.8599 - val_accuracy: 0.7200 - val_sparse_categorical_crossentropy: 0.7107
# Epoch 9/20
# 63/63 - 49s - loss: 0.6839 - accuracy: 0.7952 - sparse_categorical_crossentropy: 0.5376 - val_loss: 0.8678 - val_accuracy: 0.7300 - val_sparse_categorical_crossentropy: 0.7216
# Epoch 10/20
# 63/63 - 50s - loss: 0.6776 - accuracy: 0.7982 - sparse_categorical_crossentropy: 0.5319 - val_loss: 0.9284 - val_accuracy: 0.7180 - val_sparse_categorical_crossentropy: 0.7850
# 16/16 [==============================] - 2s 108ms/step - loss: 0.8599 - accuracy: 0.7200 - sparse_categorical_crossentropy: 0.7211
# INFO:tensorflow:Assets written to: D:/sam/Logs/Model 2/Run-6\assets
# --- Starting trial: run-7
# {'lambda': 0.005}
# Epoch 1/20
# 63/63 - 52s - loss: 2.7148 - accuracy: 0.4698 - sparse_categorical_crossentropy: 1.3871 - val_loss: 1.6093 - val_accuracy: 0.5560 - val_sparse_categorical_crossentropy: 1.0549
# Epoch 2/20
# 63/63 - 49s - loss: 1.3315 - accuracy: 0.6281 - sparse_categorical_crossentropy: 0.9221 - val_loss: 1.3031 - val_accuracy: 0.5720 - val_sparse_categorical_crossentropy: 0.9892
# Epoch 3/20
# 63/63 - 49s - loss: 1.0985 - accuracy: 0.6668 - sparse_categorical_crossentropy: 0.8222 - val_loss: 1.0934 - val_accuracy: 0.6560 - val_sparse_categorical_crossentropy: 0.8483
# Epoch 4/20
# 63/63 - 49s - loss: 1.0230 - accuracy: 0.6888 - sparse_categorical_crossentropy: 0.7831 - val_loss: 1.1821 - val_accuracy: 0.6260 - val_sparse_categorical_crossentropy: 0.9503
# Epoch 5/20
# 63/63 - 48s - loss: 0.9752 - accuracy: 0.7018 - sparse_categorical_crossentropy: 0.7473 - val_loss: 1.0648 - val_accuracy: 0.6540 - val_sparse_categorical_crossentropy: 0.8445
# Epoch 6/20
# 63/63 - 48s - loss: 0.9544 - accuracy: 0.7058 - sparse_categorical_crossentropy: 0.7362 - val_loss: 1.1123 - val_accuracy: 0.6420 - val_sparse_categorical_crossentropy: 0.8972
# Epoch 7/20
# 63/63 - 48s - loss: 0.9197 - accuracy: 0.7193 - sparse_categorical_crossentropy: 0.7109 - val_loss: 1.0023 - val_accuracy: 0.6700 - val_sparse_categorical_crossentropy: 0.7955
# Epoch 8/20
# 63/63 - 50s - loss: 0.9216 - accuracy: 0.7078 - sparse_categorical_crossentropy: 0.7051 - val_loss: 1.0451 - val_accuracy: 0.6600 - val_sparse_categorical_crossentropy: 0.8261
# Epoch 9/20
# 63/63 - 50s - loss: 0.9088 - accuracy: 0.7258 - sparse_categorical_crossentropy: 0.6947 - val_loss: 1.0548 - val_accuracy: 0.6540 - val_sparse_categorical_crossentropy: 0.8349
# 16/16 [==============================] - 2s 109ms/step - loss: 1.0023 - accuracy: 0.6700 - sparse_categorical_crossentropy: 0.8015
# INFO:tensorflow:Assets written to: D:/sam/Logs/Model 2/Run-7\assets
# --- Starting trial: run-8
# {'lambda': 0.01}
# Epoch 1/20
# 63/63 - 53s - loss: 3.6399 - accuracy: 0.4803 - sparse_categorical_crossentropy: 1.4224 - val_loss: 1.8553 - val_accuracy: 0.5300 - val_sparse_categorical_crossentropy: 1.0840
# Epoch 2/20
# 63/63 - 49s - loss: 1.5465 - accuracy: 0.6031 - sparse_categorical_crossentropy: 0.9724 - val_loss: 1.4444 - val_accuracy: 0.6000 - val_sparse_categorical_crossentropy: 0.9825
# Epoch 3/20
# 63/63 - 47s - loss: 1.3013 - accuracy: 0.6384 - sparse_categorical_crossentropy: 0.8951 - val_loss: 1.3735 - val_accuracy: 0.6200 - val_sparse_categorical_crossentropy: 0.9764
# Epoch 4/20
# 63/63 - 47s - loss: 1.2026 - accuracy: 0.6681 - sparse_categorical_crossentropy: 0.8485 - val_loss: 1.2414 - val_accuracy: 0.6160 - val_sparse_categorical_crossentropy: 0.9116
# Epoch 5/20
# 63/63 - 46s - loss: 1.1677 - accuracy: 0.6603 - sparse_categorical_crossentropy: 0.8480 - val_loss: 1.1647 - val_accuracy: 0.6600 - val_sparse_categorical_crossentropy: 0.8633
# Epoch 6/20
# 63/63 - 46s - loss: 1.0839 - accuracy: 0.6866 - sparse_categorical_crossentropy: 0.7861 - val_loss: 1.1639 - val_accuracy: 0.6320 - val_sparse_categorical_crossentropy: 0.8848
# Epoch 7/20
# 63/63 - 47s - loss: 1.0325 - accuracy: 0.6986 - sparse_categorical_crossentropy: 0.7583 - val_loss: 1.1342 - val_accuracy: 0.6900 - val_sparse_categorical_crossentropy: 0.8267
# Epoch 8/20
# 63/63 - 46s - loss: 1.0606 - accuracy: 0.6938 - sparse_categorical_crossentropy: 0.7761 - val_loss: 1.0877 - val_accuracy: 0.6600 - val_sparse_categorical_crossentropy: 0.8280
# Epoch 9/20
# 63/63 - 47s - loss: 0.9695 - accuracy: 0.7223 - sparse_categorical_crossentropy: 0.7172 - val_loss: 1.1065 - val_accuracy: 0.6800 - val_sparse_categorical_crossentropy: 0.8509
# 16/16 [==============================] - 2s 100ms/step - loss: 1.1342 - accuracy: 0.6900 - sparse_categorical_crossentropy: 0.8336
# INFO:tensorflow:Assets written to: D:/sam/Logs/Model 2/Run-8\assets
# --- Starting trial: run-9
# {'lambda': 0.05}
# Epoch 1/20
# 63/63 - 49s - loss: 8.4279 - accuracy: 0.4508 - sparse_categorical_crossentropy: 1.3871 - val_loss: 2.4125 - val_accuracy: 0.5420 - val_sparse_categorical_crossentropy: 1.1252
# Epoch 2/20
# 63/63 - 47s - loss: 2.0804 - accuracy: 0.5684 - sparse_categorical_crossentropy: 1.0442 - val_loss: 2.1154 - val_accuracy: 0.4480 - val_sparse_categorical_crossentropy: 1.2576
# Epoch 3/20
# 63/63 - 47s - loss: 1.7994 - accuracy: 0.5737 - sparse_categorical_crossentropy: 1.0326 - val_loss: 1.7714 - val_accuracy: 0.5740 - val_sparse_categorical_crossentropy: 1.0789
# Epoch 4/20
# 63/63 - 47s - loss: 1.5882 - accuracy: 0.5967 - sparse_categorical_crossentropy: 0.9806 - val_loss: 1.5829 - val_accuracy: 0.5660 - val_sparse_categorical_crossentropy: 1.0447
# Epoch 5/20
# 63/63 - 48s - loss: 1.4669 - accuracy: 0.6016 - sparse_categorical_crossentropy: 0.9669 - val_loss: 1.4559 - val_accuracy: 0.5800 - val_sparse_categorical_crossentropy: 0.9952
# Epoch 6/20
# 63/63 - 46s - loss: 1.3594 - accuracy: 0.6044 - sparse_categorical_crossentropy: 0.9434 - val_loss: 1.4399 - val_accuracy: 0.5560 - val_sparse_categorical_crossentropy: 1.0619
# Epoch 7/20
# 63/63 - 48s - loss: 1.2875 - accuracy: 0.6171 - sparse_categorical_crossentropy: 0.9335 - val_loss: 1.3189 - val_accuracy: 0.6040 - val_sparse_categorical_crossentropy: 0.9825
# Epoch 8/20
# 63/63 - 46s - loss: 1.2092 - accuracy: 0.6334 - sparse_categorical_crossentropy: 0.8962 - val_loss: 1.2845 - val_accuracy: 0.5660 - val_sparse_categorical_crossentropy: 0.9928
# Epoch 9/20
# 63/63 - 48s - loss: 1.1926 - accuracy: 0.6264 - sparse_categorical_crossentropy: 0.9084 - val_loss: 1.2421 - val_accuracy: 0.5960 - val_sparse_categorical_crossentropy: 0.9755
# Epoch 10/20
# 63/63 - 46s - loss: 1.1539 - accuracy: 0.6381 - sparse_categorical_crossentropy: 0.8943 - val_loss: 1.2298 - val_accuracy: 0.5820 - val_sparse_categorical_crossentropy: 0.9841
# Epoch 11/20
# 63/63 - 46s - loss: 1.1154 - accuracy: 0.6501 - sparse_categorical_crossentropy: 0.8690 - val_loss: 1.2006 - val_accuracy: 0.5880 - val_sparse_categorical_crossentropy: 0.9720
# Epoch 12/20
# 63/63 - 46s - loss: 1.0955 - accuracy: 0.6376 - sparse_categorical_crossentropy: 0.8647 - val_loss: 1.1838 - val_accuracy: 0.5780 - val_sparse_categorical_crossentropy: 0.9632
# Epoch 13/20
# 63/63 - 46s - loss: 1.0714 - accuracy: 0.6558 - sparse_categorical_crossentropy: 0.8482 - val_loss: 1.1114 - val_accuracy: 0.6120 - val_sparse_categorical_crossentropy: 0.8982
# Epoch 14/20
# 63/63 - 46s - loss: 1.0697 - accuracy: 0.6556 - sparse_categorical_crossentropy: 0.8539 - val_loss: 1.1506 - val_accuracy: 0.6300 - val_sparse_categorical_crossentropy: 0.9367
# Epoch 15/20
# 63/63 - 46s - loss: 1.0680 - accuracy: 0.6541 - sparse_categorical_crossentropy: 0.8591 - val_loss: 1.1587 - val_accuracy: 0.6040 - val_sparse_categorical_crossentropy: 0.9536
# 16/16 [==============================] - 2s 103ms/step - loss: 1.1114 - accuracy: 0.6120 - sparse_categorical_crossentropy: 0.9070
# INFO:tensorflow:Assets written to: D:/sam/Logs/Model 2/Run-9\assets
# --- Starting trial: run-10
# {'lambda': 0.1}
# Epoch 1/20
# 63/63 - 47s - loss: 12.8810 - accuracy: 0.3859 - sparse_categorical_crossentropy: 1.3885 - val_loss: 2.4780 - val_accuracy: 0.4960 - val_sparse_categorical_crossentropy: 1.2376
# Epoch 2/20
# 63/63 - 45s - loss: 2.0048 - accuracy: 0.4930 - sparse_categorical_crossentropy: 1.1681 - val_loss: 1.8664 - val_accuracy: 0.4180 - val_sparse_categorical_crossentropy: 1.2732
# Epoch 3/20
# 63/63 - 45s - loss: 1.6301 - accuracy: 0.5165 - sparse_categorical_crossentropy: 1.1301 - val_loss: 1.6078 - val_accuracy: 0.4980 - val_sparse_categorical_crossentropy: 1.1471
# Epoch 4/20
# 63/63 - 47s - loss: 1.4735 - accuracy: 0.5342 - sparse_categorical_crossentropy: 1.0870 - val_loss: 1.4662 - val_accuracy: 0.5040 - val_sparse_categorical_crossentropy: 1.1409
# Epoch 5/20
# 63/63 - 45s - loss: 1.3589 - accuracy: 0.5619 - sparse_categorical_crossentropy: 1.0400 - val_loss: 1.4093 - val_accuracy: 0.4860 - val_sparse_categorical_crossentropy: 1.1302
# Epoch 6/20
# 63/63 - 45s - loss: 1.3234 - accuracy: 0.5612 - sparse_categorical_crossentropy: 1.0347 - val_loss: 1.3464 - val_accuracy: 0.4760 - val_sparse_categorical_crossentropy: 1.0857
# Epoch 7/20
# 63/63 - 45s - loss: 1.2793 - accuracy: 0.5782 - sparse_categorical_crossentropy: 1.0103 - val_loss: 1.4729 - val_accuracy: 0.4860 - val_sparse_categorical_crossentropy: 1.2044
# Epoch 8/20
# 63/63 - 47s - loss: 1.2629 - accuracy: 0.5737 - sparse_categorical_crossentropy: 1.0128 - val_loss: 1.2678 - val_accuracy: 0.5460 - val_sparse_categorical_crossentropy: 1.0279
# Epoch 9/20
# 63/63 - 45s - loss: 1.2111 - accuracy: 0.6019 - sparse_categorical_crossentropy: 0.9656 - val_loss: 1.3098 - val_accuracy: 0.5400 - val_sparse_categorical_crossentropy: 1.0790
# Epoch 10/20
# 63/63 - 46s - loss: 1.1995 - accuracy: 0.6009 - sparse_categorical_crossentropy: 0.9676 - val_loss: 1.2371 - val_accuracy: 0.5780 - val_sparse_categorical_crossentropy: 1.0182
# Epoch 11/20
# 63/63 - 45s - loss: 1.2309 - accuracy: 0.5759 - sparse_categorical_crossentropy: 1.0071 - val_loss: 1.2856 - val_accuracy: 0.5260 - val_sparse_categorical_crossentropy: 1.0691
# Epoch 12/20
# 63/63 - 46s - loss: 1.1884 - accuracy: 0.5877 - sparse_categorical_crossentropy: 0.9717 - val_loss: 1.2248 - val_accuracy: 0.5620 - val_sparse_categorical_crossentropy: 0.9965
# Epoch 13/20
# 63/63 - 47s - loss: 1.1341 - accuracy: 0.6251 - sparse_categorical_crossentropy: 0.9155 - val_loss: 1.2490 - val_accuracy: 0.5100 - val_sparse_categorical_crossentropy: 1.0251
# Epoch 14/20
# 63/63 - 45s - loss: 1.1688 - accuracy: 0.6079 - sparse_categorical_crossentropy: 0.9449 - val_loss: 1.1884 - val_accuracy: 0.5480 - val_sparse_categorical_crossentropy: 0.9933
# Epoch 15/20
# 63/63 - 45s - loss: 1.1421 - accuracy: 0.6119 - sparse_categorical_crossentropy: 0.9243 - val_loss: 1.2820 - val_accuracy: 0.5640 - val_sparse_categorical_crossentropy: 1.0345
# Epoch 16/20
# 63/63 - 45s - loss: 1.1641 - accuracy: 0.5999 - sparse_categorical_crossentropy: 0.9480 - val_loss: 1.1513 - val_accuracy: 0.6080 - val_sparse_categorical_crossentropy: 0.9429
# Epoch 17/20
# 63/63 - 47s - loss: 1.1093 - accuracy: 0.6266 - sparse_categorical_crossentropy: 0.9018 - val_loss: 1.1711 - val_accuracy: 0.6120 - val_sparse_categorical_crossentropy: 0.9541
# Epoch 18/20
# 63/63 - 45s - loss: 1.1088 - accuracy: 0.6354 - sparse_categorical_crossentropy: 0.8967 - val_loss: 1.1797 - val_accuracy: 0.5760 - val_sparse_categorical_crossentropy: 0.9764
# 16/16 [==============================] - 2s 98ms/step - loss: 1.1513 - accuracy: 0.6080 - sparse_categorical_crossentropy: 0.9474
# INFO:tensorflow:Assets written to: D:/sam/Logs/Model 2/Run-10\assets

# %%
# %load_ext tensorboard
# %tensorboard --logdir "D:/sam/Logs/Model 2/fit"
# Out:
#       <iframe id="tensorboard-frame-946be5a3a9993040" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-946be5a3a9993040");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %load_ext tensorboard
# %tensorboard --logdir "D:/sam/Logs/Model 2/hparam_tuning"
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-25ff194e9f00bea7" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-25ff194e9f00bea7");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
