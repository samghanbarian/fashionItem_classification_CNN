# %%
import io
import itertools

import numpy as np
import sklearn.metrics
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorboard.plugins.hparams import api as hp

# %%
#loading the data
train_data = np.load(r'datasets/Trousers & Jeans - Male - Train.npz')
val_data = np.load(r'datasets/Trousers & Jeans - Male - Validation.npz')
test_data = np.load(r'datasets/Trousers & Jeans - Male - Test.npz')

# %%
train_images, train_labels = train_data['images'], train_data['labels']
val_images, val_labels = val_data['images'], val_data['labels']
test_images, test_labels = test_data['images'], test_data['labels']

# %%
# scaling
train_images = train_images/255.
val_images = val_images/255.
test_images = test_images/255.

# %%
#constant definition
NUM_EPOCHS = 15
BATCH_SIZE = 64

# %%
#hyperparam definition
HP_FILTER_SIZE = hp.HParam('filter_size', hp.Discrete([5,7]))
HP_NUM_FILTER = hp.HParam('filters_number', hp.Discrete([64,96,128]))
# HP_FILTER_SIZE_2 = hp.HParam('filter_size_2', hp.Discrete([3,5]))
HP_DENSE_SIZE = hp.HParam('dense_size', hp.Discrete([512,1024]))

METRIC_ACCURACY = 'accuracy'

with tf.summary.create_file_writer(r'D:/sam/Logs/Model 7/hparam_tuning/').as_default():
    hp.hparams_config(
        hparams= [HP_FILTER_SIZE,HP_NUM_FILTER,HP_DENSE_SIZE],
        metrics = [hp.Metric(METRIC_ACCURACY,display_name='accuracy')]
    )

# %%
#model definition and training
def train_test_model(hparams,session_num):
    
    #model outline
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(hparams[HP_NUM_FILTER],hparams[HP_FILTER_SIZE], activation='relu', input_shape=(120,90,3)),
        tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
        tf.keras.layers.Conv2D(hparams[HP_NUM_FILTER],5,activation='relu'),
        tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(hparams[HP_DENSE_SIZE], activation='relu'),
        tf.keras.layers.Dense(4)
    ])
    
    
    loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
    
    model.compile(optimizer='adam', loss= loss_fn, metrics=['accuracy'])
    
    #defining the logging dir
    log_dir = 'D:/sam/Logs/Model 7/fit/'+'run-{}'.format(session_num)
    
    def plot_confusion_matrix(cm, class_names):
        figure = plt.figure(figsize=(12, 12))
        plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
        plt.title("Confusion matrix")
        plt.colorbar()
        tick_marks = np.arange(len(class_names))
        plt.xticks(tick_marks, class_names, rotation=45)
        plt.yticks(tick_marks, class_names)

        # Normalize the confusion matrix
        cm = np.around(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], decimals=2)

        # Use white text if squares are dark; otherwise black.
        threshold = cm.max() / 2.
        for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            color = "white" if cm[i, j] > threshold else "black"
            plt.text(j, i, cm[i, j], horizontalalignment="center", color=color)

        plt.tight_layout()
        plt.ylabel('True label')
        plt.xlabel('Predicted label') 
        return figure

    def plot_to_image(figure):
    
        #save the plot to a png in memory
        buf = io.BytesIO()
        plt.savefig(buf, format='png')
    
        #closing the figure to prevent from displaying in the notebook
        plt.close(figure)
    
        buf.seek(0)
    
        image = tf.image.decode_png(buf.getvalue(), channels=4)
    
        #add the batch dimension
        image = tf.expand_dims(image, 0)
    
        return image

    #file writer for logging cofusion matrix
    file_writer_cm = tf.summary.create_file_writer(log_dir + '/cm')
    
    def log_confusion_matrix(epoch, logs):
    #predict values for validation set
        test_pred_r = model.predict(val_images)
        test_pred = np.argmax(test_pred_r, axis=1)
    
        cm = sklearn.metrics.confusion_matrix(val_labels, test_pred)
    
        figure = plot_confusion_matrix(cm, class_names=['Jeans', 'Trousers'])
        cm_image = plot_to_image(figure)
    
        #log the confusion matrix as image summary
        with file_writer_cm.as_default():
            tf.summary.image('Confusion Matrix', cm_image, step=epoch)
            
    
    
    #defining callbacks
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir,histogram_freq = 1, profile_batch = 0)
    cm_callback = tf.keras.callbacks.LambdaCallback(on_epoch_end= log_confusion_matrix)
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        mode = 'auto',
        verbose=0,
        patience = 2,
        min_delta = 0,
        restore_best_weights= True
    )

    
    #training the model
    model.fit(
        train_images,
        train_labels,
        validation_data= (val_images,val_labels),
        verbose=2,
        epochs= NUM_EPOCHS,
        batch_size = BATCH_SIZE,
        callbacks=[tensorboard_callback,cm_callback,early_stopping]
        
    )
    
    #model performance evaluation
    _, accuracy = model.evaluate(val_images,val_labels)
    
    #saving the model
    model.save(r'D:/sam/saved Models/Model 7/Run-{}'.format(session_num))
    
    return accuracy

# %%
#logging the result function
def run(log_dir, hparams, session_num):
    
    with tf.summary.create_file_writer(log_dir).as_default():
        hp.hparams(hparams)  # record the values used in this trial
        accuracy = train_test_model(hparams, session_num)
        tf.summary.scalar(METRIC_ACCURACY, accuracy, step=1)

# %%
session_num = 1

for filter_size in HP_FILTER_SIZE.domain.values:
    for num_filter in HP_NUM_FILTER.domain.values:
#         for filter_size_2 in HP_FILTER_SIZE_2.domain.values:
            for dense_size in HP_DENSE_SIZE.domain.values:
        
                hparams = {
                    HP_FILTER_SIZE : filter_size,
                    HP_NUM_FILTER : num_filter,
                    HP_DENSE_SIZE: dense_size
                }
        
                run_name = 'run-%d' %session_num
                print('---- Starting trial : %s' % run_name)
                print({h.name: hparams[h] for h in hparams})
                run('D:/sam/Logs/Model 7/hparam_tuning/' +run_name, hparams, session_num)
        
                session_num += 1
# Out:
# ---- Starting trial : run-1
# {'filter_size': 5, 'filters_number': 64, 'dense_size': 512}
# Epoch 1/15
# 32/32 - 36s - loss: 1.0043 - accuracy: 0.5340 - val_loss: 0.6181 - val_accuracy: 0.6280
# Epoch 2/15
# 32/32 - 33s - loss: 0.5211 - accuracy: 0.7532 - val_loss: 0.5034 - val_accuracy: 0.7360
# Epoch 3/15
# 32/32 - 31s - loss: 0.4557 - accuracy: 0.7967 - val_loss: 0.4119 - val_accuracy: 0.8240
# Epoch 4/15
# 32/32 - 31s - loss: 0.4478 - accuracy: 0.7902 - val_loss: 0.4068 - val_accuracy: 0.8160
# Epoch 5/15
# 32/32 - 31s - loss: 0.3881 - accuracy: 0.8232 - val_loss: 0.3765 - val_accuracy: 0.8560
# Epoch 6/15
# 32/32 - 31s - loss: 0.3679 - accuracy: 0.8297 - val_loss: 0.3605 - val_accuracy: 0.8600
# Epoch 7/15
# 32/32 - 31s - loss: 0.3760 - accuracy: 0.8352 - val_loss: 0.4532 - val_accuracy: 0.7960
# Epoch 8/15
# 32/32 - 31s - loss: 0.3753 - accuracy: 0.8207 - val_loss: 0.3899 - val_accuracy: 0.8120
# 8/8 [==============================] - 1s 110ms/step - loss: 0.3605 - accuracy: 0.8600
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 7/Run-1\assets
# ---- Starting trial : run-2
# {'filter_size': 5, 'filters_number': 64, 'dense_size': 1024}
# Epoch 1/15
# 32/32 - 36s - loss: 1.2380 - accuracy: 0.5949 - val_loss: 0.7849 - val_accuracy: 0.6160
# Epoch 2/15
# 32/32 - 36s - loss: 0.5479 - accuracy: 0.7263 - val_loss: 0.5498 - val_accuracy: 0.7280
# Epoch 3/15
# 32/32 - 34s - loss: 0.4562 - accuracy: 0.7852 - val_loss: 0.4625 - val_accuracy: 0.7720
# Epoch 4/15
# 32/32 - 34s - loss: 0.4444 - accuracy: 0.7922 - val_loss: 0.4408 - val_accuracy: 0.8000
# Epoch 5/15
# 32/32 - 35s - loss: 0.4098 - accuracy: 0.8187 - val_loss: 0.4377 - val_accuracy: 0.7960
# Epoch 6/15
# 32/32 - 37s - loss: 0.4032 - accuracy: 0.8032 - val_loss: 0.4355 - val_accuracy: 0.7840
# Epoch 7/15
# 32/32 - 34s - loss: 0.3869 - accuracy: 0.8197 - val_loss: 0.4043 - val_accuracy: 0.8160
# Epoch 8/15
# 32/32 - 34s - loss: 0.3645 - accuracy: 0.8307 - val_loss: 0.3857 - val_accuracy: 0.8200
# Epoch 9/15
# 32/32 - 34s - loss: 0.3808 - accuracy: 0.8162 - val_loss: 0.4110 - val_accuracy: 0.8080
# Epoch 10/15
# 32/32 - 34s - loss: 0.3487 - accuracy: 0.8372 - val_loss: 0.4334 - val_accuracy: 0.8240
# 8/8 [==============================] - 1s 117ms/step - loss: 0.3857 - accuracy: 0.8200
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 7/Run-2\assets
# ---- Starting trial : run-3
# {'filter_size': 5, 'filters_number': 96, 'dense_size': 512}
# Epoch 1/15
# 32/32 - 53s - loss: 1.7513 - accuracy: 0.5365 - val_loss: 0.6992 - val_accuracy: 0.5480
# Epoch 2/15
# 32/32 - 50s - loss: 0.5516 - accuracy: 0.7288 - val_loss: 0.5037 - val_accuracy: 0.7480
# Epoch 3/15
# 32/32 - 50s - loss: 0.4584 - accuracy: 0.7857 - val_loss: 0.4459 - val_accuracy: 0.8120
# Epoch 4/15
# 32/32 - 50s - loss: 0.4110 - accuracy: 0.8057 - val_loss: 0.4044 - val_accuracy: 0.8080
# Epoch 5/15
# 32/32 - 50s - loss: 0.4146 - accuracy: 0.8067 - val_loss: 0.6158 - val_accuracy: 0.7560
# Epoch 6/15
# 32/32 - 50s - loss: 0.3901 - accuracy: 0.8232 - val_loss: 0.3686 - val_accuracy: 0.8360
# Epoch 7/15
# 32/32 - 52s - loss: 0.3406 - accuracy: 0.8506 - val_loss: 0.3789 - val_accuracy: 0.8280
# Epoch 8/15
# 32/32 - 50s - loss: 0.3427 - accuracy: 0.8422 - val_loss: 0.3866 - val_accuracy: 0.8240
# 8/8 [==============================] - 2s 192ms/step - loss: 0.3686 - accuracy: 0.8360
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 7/Run-3\assets
# ---- Starting trial : run-4
# {'filter_size': 5, 'filters_number': 96, 'dense_size': 1024}
# Epoch 1/15
# 32/32 - 59s - loss: 1.6121 - accuracy: 0.5485 - val_loss: 0.5931 - val_accuracy: 0.7200
# Epoch 2/15
# 32/32 - 55s - loss: 0.5539 - accuracy: 0.7288 - val_loss: 0.5294 - val_accuracy: 0.7760
# Epoch 3/15
# 32/32 - 55s - loss: 0.4831 - accuracy: 0.7607 - val_loss: 0.4995 - val_accuracy: 0.8080
# Epoch 4/15
# 32/32 - 55s - loss: 0.4588 - accuracy: 0.7747 - val_loss: 0.4769 - val_accuracy: 0.7720
# Epoch 5/15
# 32/32 - 55s - loss: 0.4015 - accuracy: 0.8092 - val_loss: 0.6428 - val_accuracy: 0.7160
# Epoch 6/15
# 32/32 - 55s - loss: 0.4118 - accuracy: 0.7952 - val_loss: 0.4635 - val_accuracy: 0.8080
# Epoch 7/15
# 32/32 - 55s - loss: 0.3737 - accuracy: 0.8227 - val_loss: 0.4065 - val_accuracy: 0.8040
# Epoch 8/15
# 32/32 - 55s - loss: 0.3805 - accuracy: 0.8242 - val_loss: 0.4133 - val_accuracy: 0.8280
# Epoch 9/15
# 32/32 - 55s - loss: 0.3476 - accuracy: 0.8397 - val_loss: 0.3571 - val_accuracy: 0.8640
# Epoch 10/15
# 32/32 - 55s - loss: 0.4197 - accuracy: 0.7962 - val_loss: 0.4610 - val_accuracy: 0.7720
# Epoch 11/15
# 32/32 - 55s - loss: 0.3545 - accuracy: 0.8317 - val_loss: 0.3681 - val_accuracy: 0.8400
# 8/8 [==============================] - 2s 198ms/step - loss: 0.3571 - accuracy: 0.8640
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 7/Run-4\assets
# ---- Starting trial : run-5
# {'filter_size': 5, 'filters_number': 128, 'dense_size': 512}
# Epoch 1/15
# 32/32 - 78s - loss: 2.1881 - accuracy: 0.5350 - val_loss: 0.6866 - val_accuracy: 0.5280
# Epoch 2/15
# 32/32 - 74s - loss: 0.5559 - accuracy: 0.7093 - val_loss: 0.5612 - val_accuracy: 0.7480
# Epoch 3/15
# 32/32 - 74s - loss: 0.4839 - accuracy: 0.7702 - val_loss: 0.4170 - val_accuracy: 0.8080
# Epoch 4/15
# 32/32 - 75s - loss: 0.4336 - accuracy: 0.7917 - val_loss: 0.4219 - val_accuracy: 0.7920
# Epoch 5/15
# 32/32 - 75s - loss: 0.3982 - accuracy: 0.8142 - val_loss: 0.4881 - val_accuracy: 0.7880
# 8/8 [==============================] - 2s 287ms/step - loss: 0.4170 - accuracy: 0.8080
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 7/Run-5\assets
# ---- Starting trial : run-6
# {'filter_size': 5, 'filters_number': 128, 'dense_size': 1024}
# Epoch 1/15
# 32/32 - 85s - loss: 1.9155 - accuracy: 0.5490 - val_loss: 0.5688 - val_accuracy: 0.7120
# Epoch 2/15
# 32/32 - 81s - loss: 0.5190 - accuracy: 0.7438 - val_loss: 0.5025 - val_accuracy: 0.7640
# Epoch 3/15
# 32/32 - 81s - loss: 0.4700 - accuracy: 0.7707 - val_loss: 0.4403 - val_accuracy: 0.7880
# Epoch 4/15
# 32/32 - 81s - loss: 0.4289 - accuracy: 0.8097 - val_loss: 0.4768 - val_accuracy: 0.7760
# Epoch 5/15
# 32/32 - 82s - loss: 0.4341 - accuracy: 0.8012 - val_loss: 0.4113 - val_accuracy: 0.7960
# Epoch 6/15
# 32/32 - 81s - loss: 0.3842 - accuracy: 0.8217 - val_loss: 0.3939 - val_accuracy: 0.8240
# Epoch 7/15
# 32/32 - 82s - loss: 0.3614 - accuracy: 0.8292 - val_loss: 0.3760 - val_accuracy: 0.8520
# Epoch 8/15
# 32/32 - 81s - loss: 0.3356 - accuracy: 0.8521 - val_loss: 0.3670 - val_accuracy: 0.8320
# Epoch 9/15
# 32/32 - 81s - loss: 0.3088 - accuracy: 0.8621 - val_loss: 0.3260 - val_accuracy: 0.8600
# Epoch 10/15
# 32/32 - 82s - loss: 0.2904 - accuracy: 0.8706 - val_loss: 0.4780 - val_accuracy: 0.7760
# Epoch 11/15
# 32/32 - 81s - loss: 0.3274 - accuracy: 0.8492 - val_loss: 0.6251 - val_accuracy: 0.7840
# 8/8 [==============================] - 3s 310ms/step - loss: 0.3260 - accuracy: 0.8600
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 7/Run-6\assets
# ---- Starting trial : run-7
# {'filter_size': 7, 'filters_number': 64, 'dense_size': 512}
# Epoch 1/15
# 32/32 - 34s - loss: 1.2658 - accuracy: 0.5405 - val_loss: 0.5869 - val_accuracy: 0.7040
# Epoch 2/15
# 32/32 - 33s - loss: 0.5248 - accuracy: 0.7458 - val_loss: 0.5690 - val_accuracy: 0.7280
# Epoch 3/15
# 32/32 - 33s - loss: 0.5179 - accuracy: 0.7627 - val_loss: 0.5426 - val_accuracy: 0.7880
# Epoch 4/15
# 32/32 - 33s - loss: 0.4354 - accuracy: 0.7927 - val_loss: 0.4584 - val_accuracy: 0.7840
# Epoch 5/15
# 32/32 - 33s - loss: 0.4135 - accuracy: 0.8112 - val_loss: 0.4232 - val_accuracy: 0.7880
# Epoch 6/15
# 32/32 - 34s - loss: 0.4206 - accuracy: 0.7947 - val_loss: 0.4337 - val_accuracy: 0.8080
# Epoch 7/15
# 32/32 - 33s - loss: 0.3739 - accuracy: 0.8257 - val_loss: 0.4363 - val_accuracy: 0.8200
# 8/8 [==============================] - 1s 111ms/step - loss: 0.4232 - accuracy: 0.7880
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 7/Run-7\assets
# ---- Starting trial : run-8
# {'filter_size': 7, 'filters_number': 64, 'dense_size': 1024}
# Epoch 1/15
# 32/32 - 37s - loss: 1.7595 - accuracy: 0.5559 - val_loss: 0.6642 - val_accuracy: 0.5480
# Epoch 2/15
# 32/32 - 36s - loss: 0.5518 - accuracy: 0.7068 - val_loss: 0.4681 - val_accuracy: 0.7880
# Epoch 3/15
# 32/32 - 37s - loss: 0.4615 - accuracy: 0.7787 - val_loss: 0.4625 - val_accuracy: 0.7920
# Epoch 4/15
# 32/32 - 37s - loss: 0.4275 - accuracy: 0.8037 - val_loss: 0.4121 - val_accuracy: 0.8120
# Epoch 5/15
# 32/32 - 37s - loss: 0.4107 - accuracy: 0.8062 - val_loss: 0.4387 - val_accuracy: 0.8000
# Epoch 6/15
# 32/32 - 38s - loss: 0.3929 - accuracy: 0.8162 - val_loss: 0.4183 - val_accuracy: 0.8080
# 8/8 [==============================] - 1s 131ms/step - loss: 0.4121 - accuracy: 0.8120
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 7/Run-8\assets
# ---- Starting trial : run-9
# {'filter_size': 7, 'filters_number': 96, 'dense_size': 512}
# Epoch 1/15
# 32/32 - 54s - loss: 1.1455 - accuracy: 0.5874 - val_loss: 1.5001 - val_accuracy: 0.5280
# Epoch 2/15
# 32/32 - 52s - loss: 0.6365 - accuracy: 0.6768 - val_loss: 1.2977 - val_accuracy: 0.5240
# Epoch 3/15
# 32/32 - 52s - loss: 0.5203 - accuracy: 0.7458 - val_loss: 0.5370 - val_accuracy: 0.7480
# Epoch 4/15
# 32/32 - 52s - loss: 0.4667 - accuracy: 0.7667 - val_loss: 0.4888 - val_accuracy: 0.7480
# Epoch 5/15
# 32/32 - 52s - loss: 0.4460 - accuracy: 0.7777 - val_loss: 0.4473 - val_accuracy: 0.8120
# Epoch 6/15
# 32/32 - 52s - loss: 0.4309 - accuracy: 0.7857 - val_loss: 0.5298 - val_accuracy: 0.7360
# Epoch 7/15
# 32/32 - 56s - loss: 0.4392 - accuracy: 0.7917 - val_loss: 0.4081 - val_accuracy: 0.8040
# Epoch 8/15
# 32/32 - 52s - loss: 0.3770 - accuracy: 0.8267 - val_loss: 0.4327 - val_accuracy: 0.7960
# Epoch 9/15
# 32/32 - 55s - loss: 0.3626 - accuracy: 0.8282 - val_loss: 0.3952 - val_accuracy: 0.8000
# Epoch 10/15
# 32/32 - 52s - loss: 0.3579 - accuracy: 0.8372 - val_loss: 0.3756 - val_accuracy: 0.8040
# Epoch 11/15
# 32/32 - 54s - loss: 0.3322 - accuracy: 0.8531 - val_loss: 0.5948 - val_accuracy: 0.7720
# Epoch 12/15
# 32/32 - 54s - loss: 0.3570 - accuracy: 0.8462 - val_loss: 0.3809 - val_accuracy: 0.8280
# 8/8 [==============================] - 2s 193ms/step - loss: 0.3756 - accuracy: 0.8040
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 7/Run-9\assets
# ---- Starting trial : run-10
# {'filter_size': 7, 'filters_number': 96, 'dense_size': 1024}
# Epoch 1/15
# 32/32 - 60s - loss: 1.4863 - accuracy: 0.5614 - val_loss: 0.5993 - val_accuracy: 0.7360
# Epoch 2/15
# 32/32 - 58s - loss: 0.6454 - accuracy: 0.6728 - val_loss: 0.5367 - val_accuracy: 0.7320
# Epoch 3/15
# 32/32 - 59s - loss: 0.4935 - accuracy: 0.7587 - val_loss: 0.5183 - val_accuracy: 0.7320
# Epoch 4/15
# 32/32 - 59s - loss: 0.4759 - accuracy: 0.7687 - val_loss: 0.4446 - val_accuracy: 0.7960
# Epoch 5/15
# 32/32 - 58s - loss: 0.4460 - accuracy: 0.7902 - val_loss: 0.4539 - val_accuracy: 0.7720
# Epoch 6/15
# 32/32 - 59s - loss: 0.4278 - accuracy: 0.8012 - val_loss: 0.4122 - val_accuracy: 0.8000
# Epoch 7/15
# 32/32 - 58s - loss: 0.4081 - accuracy: 0.8062 - val_loss: 0.4124 - val_accuracy: 0.8040
# Epoch 8/15
# 32/32 - 61s - loss: 0.4102 - accuracy: 0.8017 - val_loss: 0.4006 - val_accuracy: 0.8320
# Epoch 9/15
# 32/32 - 60s - loss: 0.3828 - accuracy: 0.8177 - val_loss: 0.4316 - val_accuracy: 0.8080
# Epoch 10/15
# 32/32 - 61s - loss: 0.3859 - accuracy: 0.8222 - val_loss: 0.3751 - val_accuracy: 0.8200
# Epoch 11/15
# 32/32 - 60s - loss: 0.3776 - accuracy: 0.8257 - val_loss: 0.3867 - val_accuracy: 0.8000
# Epoch 12/15
# 32/32 - 61s - loss: 0.3613 - accuracy: 0.8357 - val_loss: 0.3749 - val_accuracy: 0.8200
# Epoch 13/15
# 32/32 - 61s - loss: 0.3503 - accuracy: 0.8302 - val_loss: 0.3648 - val_accuracy: 0.8360
# Epoch 14/15
# 32/32 - 60s - loss: 0.3468 - accuracy: 0.8342 - val_loss: 0.4960 - val_accuracy: 0.8120
# Epoch 15/15
# 32/32 - 61s - loss: 0.3652 - accuracy: 0.8397 - val_loss: 0.3541 - val_accuracy: 0.8280
# 8/8 [==============================] - 2s 222ms/step - loss: 0.3541 - accuracy: 0.8280
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 7/Run-10\assets
# ---- Starting trial : run-11
# {'filter_size': 7, 'filters_number': 128, 'dense_size': 512}
# Epoch 1/15
# 32/32 - 85s - loss: 1.6940 - accuracy: 0.5549 - val_loss: 0.6380 - val_accuracy: 0.6800
# Epoch 2/15
# 32/32 - 82s - loss: 0.5716 - accuracy: 0.6968 - val_loss: 0.5565 - val_accuracy: 0.7080
# Epoch 3/15
# 32/32 - 82s - loss: 0.5132 - accuracy: 0.7542 - val_loss: 0.4960 - val_accuracy: 0.7760
# Epoch 4/15
# 32/32 - 84s - loss: 0.4940 - accuracy: 0.7577 - val_loss: 0.4489 - val_accuracy: 0.7960
# Epoch 5/15
# 32/32 - 83s - loss: 0.4705 - accuracy: 0.7687 - val_loss: 0.4446 - val_accuracy: 0.7840
# Epoch 6/15
# 32/32 - 83s - loss: 0.4430 - accuracy: 0.7837 - val_loss: 0.4713 - val_accuracy: 0.7680
# Epoch 7/15
# 32/32 - 82s - loss: 0.4331 - accuracy: 0.7947 - val_loss: 0.4934 - val_accuracy: 0.7400
# 8/8 [==============================] - 3s 320ms/step - loss: 0.4446 - accuracy: 0.7840
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 7/Run-11\assets
# ---- Starting trial : run-12
# {'filter_size': 7, 'filters_number': 128, 'dense_size': 1024}
# Epoch 1/15
# 32/32 - 90s - loss: 2.0893 - accuracy: 0.5290 - val_loss: 0.6330 - val_accuracy: 0.6840
# Epoch 2/15
# 32/32 - 89s - loss: 0.5710 - accuracy: 0.7173 - val_loss: 0.5203 - val_accuracy: 0.7400
# Epoch 3/15
# 32/32 - 91s - loss: 0.4798 - accuracy: 0.7732 - val_loss: 0.4407 - val_accuracy: 0.7720
# Epoch 4/15
# 32/32 - 88s - loss: 0.4445 - accuracy: 0.7757 - val_loss: 0.4623 - val_accuracy: 0.7640
# Epoch 5/15
# 32/32 - 87s - loss: 0.3945 - accuracy: 0.8087 - val_loss: 0.3917 - val_accuracy: 0.8160
# Epoch 6/15
# 32/32 - 88s - loss: 0.3888 - accuracy: 0.8132 - val_loss: 0.4547 - val_accuracy: 0.8040
# Epoch 7/15
# 32/32 - 87s - loss: 0.3836 - accuracy: 0.8197 - val_loss: 0.5362 - val_accuracy: 0.7640
# 8/8 [==============================] - 3s 329ms/step - loss: 0.3917 - accuracy: 0.8160
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 7/Run-12\assets

# %%
# Loading a model to evaluate on the test set
model = tf.keras.models.load_model(r"D:/sam/saved Models/Model 7/Run-4")

# %%
test_loss, test_accuracy = model.evaluate(test_images,test_labels)
# Out:
# 8/8 [==============================] - 2s 202ms/step - loss: 0.4021 - accuracy: 0.8280

# %%
# Printing the test results
print('Test loss: {0:.4f}. Test accuracy: {1:.2f}%'.format(test_loss, test_accuracy*100.))
# Out:
# Test loss: 0.4021. Test accuracy: 82.80%

# %%
# %load_ext tensorboard
# %tensorboard --logdir "D:/sam/Logs/Model 7/hparam_tuning"
# Out:
#       <iframe id="tensorboard-frame-b9d29449abd83431" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-b9d29449abd83431");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %load_ext tensorboard
# %tensorboard --logdir "D:/sam/Logs/Model 7/fit"
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-20fed03834c58894" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-20fed03834c58894");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
