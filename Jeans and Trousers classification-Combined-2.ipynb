# %%
import io
import itertools

import numpy as np
import sklearn.metrics
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorboard.plugins.hparams import api as hp

# %%
#loading the data
train_data = np.load(r'datasets/Trousers & Jeans - All - Train.npz')
val_data = np.load(r'datasets/Trousers & Jeans - All - Validation.npz')
test_data = np.load(r'datasets/Trousers & Jeans - All - Test.npz')

# %%
train_images, train_labels = train_data['images'], train_data['labels']
val_images, val_labels = val_data['images'], val_data['labels']
test_images, test_labels = test_data['images'], test_data['labels']

# %%
#feature scaling
train_images = train_images/255.
val_images = val_images/255.
test_images = test_images/255.

# %%
#constant definition
NUM_EPOCHS = 15
BATCH_SIZE = 64

# %%
#hyperparam definition
HP_FILTER_SIZE = hp.HParam('filter_size', hp.Discrete([5,7]))
HP_NUM_FILTER = hp.HParam('filters_number', hp.Discrete([64,96,128]))
HP_FILTER_SIZE_2 = hp.HParam('filter_size_2', hp.Discrete([3,5]))
HP_DENSE_SIZE = hp.HParam('dense_size', hp.Discrete([512,1024]))

METRIC_ACCURACY = 'accuracy'

with tf.summary.create_file_writer(r'D:/sam/Logs/Model 4/hparam_tuning/').as_default():
    hp.hparams_config(
        hparams= [HP_FILTER_SIZE,HP_NUM_FILTER,HP_FILTER_SIZE_2,HP_DENSE_SIZE],
        metrics = [hp.Metric(METRIC_ACCURACY,display_name='accuracy')]
    )

# %%
#model definition and training
def train_test_model(hparams,session_num):
    
    #model outline
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(hparams[HP_NUM_FILTER],hparams[HP_FILTER_SIZE], activation='relu', input_shape=(120,90,3)),
        tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
        tf.keras.layers.Conv2D(hparams[HP_NUM_FILTER],hparams[HP_FILTER_SIZE_2],activation='relu'),
        tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(hparams[HP_DENSE_SIZE], activation='relu'),
        tf.keras.layers.Dense(4)
    ])
    
    
    loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
    
    model.compile(optimizer='adam', loss= loss_fn, metrics=['accuracy'])
    
    #defining the logging dir
    log_dir = 'D:/sam/Logs/Model 4/fit/'+'run-{}'.format(session_num)
    
    def plot_confusion_matrix(cm, class_names):
        figure = plt.figure(figsize=(12, 12))
        plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
        plt.title("Confusion matrix")
        plt.colorbar()
        tick_marks = np.arange(len(class_names))
        plt.xticks(tick_marks, class_names, rotation=45)
        plt.yticks(tick_marks, class_names)

        # Normalize the confusion matrix
        cm = np.around(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], decimals=2)

        # Use white text if squares are dark; otherwise black.
        threshold = cm.max() / 2.
        for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            color = "white" if cm[i, j] > threshold else "black"
            plt.text(j, i, cm[i, j], horizontalalignment="center", color=color)

        plt.tight_layout()
        plt.ylabel('True label')
        plt.xlabel('Predicted label') 
        return figure

    def plot_to_image(figure):
    
        #save the plot to a png in memory
        buf = io.BytesIO()
        plt.savefig(buf, format='png')
    
        #closing the figure to prevent from displaying in the notebook
        plt.close(figure)
    
        buf.seek(0)
    
        image = tf.image.decode_png(buf.getvalue(), channels=4)
    
        #add the batch dimension
        image = tf.expand_dims(image, 0)
    
        return image

    #file writer for logging cofusion matrix
    file_writer_cm = tf.summary.create_file_writer(log_dir + '/cm')
    
    def log_confusion_matrix(epoch, logs):
    #predict values for validation set
        test_pred_r = model.predict(val_images)
        test_pred = np.argmax(test_pred_r, axis=1)
    
        cm = sklearn.metrics.confusion_matrix(val_labels, test_pred)
    
        figure = plot_confusion_matrix(cm, class_names=['Trousers Male', 'Jeans Male', 'Trousers Female', 'Jeans Female'])
        cm_image = plot_to_image(figure)
    
        #log the confusion matrix as image summary
        with file_writer_cm.as_default():
            tf.summary.image('Confusion Matrix', cm_image, step=epoch)
            
    
    
    #defining callbacks
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir,histogram_freq = 1, profile_batch = 0)
    cm_callback = tf.keras.callbacks.LambdaCallback(on_epoch_end= log_confusion_matrix)
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        mode = 'auto',
        verbose=0,
        patience = 2,
        min_delta = 0,
        restore_best_weights= True
    )

    
    #training the model
    model.fit(
        train_images,
        train_labels,
        validation_data= (val_images,val_labels),
        verbose=2,
        epochs= NUM_EPOCHS,
        batch_size = BATCH_SIZE,
        callbacks=[tensorboard_callback,cm_callback,early_stopping]
        
    )
    
    #model performance evaluation
    _, accuracy = model.evaluate(val_images,val_labels)
    
    #saving the model
    model.save(r'D:/sam/saved Models/Model 4/Run-{}'.format(session_num))
    
    return accuracy

# %%
#logging the result function
def run(log_dir, hparams, session_num):
    
    with tf.summary.create_file_writer(log_dir).as_default():
        hp.hparams(hparams)  # record the values used in this trial
        accuracy = train_test_model(hparams, session_num)
        tf.summary.scalar(METRIC_ACCURACY, accuracy, step=1)

# %%
session_num = 1

for filter_size in HP_FILTER_SIZE.domain.values:
    for num_filter in HP_NUM_FILTER.domain.values:
        for filter_size_2 in HP_FILTER_SIZE_2.domain.values:
            for dense_size in HP_DENSE_SIZE.domain.values:
        
                hparams = {
                    HP_FILTER_SIZE : filter_size,
                    HP_NUM_FILTER : num_filter,
                    HP_FILTER_SIZE_2: filter_size_2,
                    HP_DENSE_SIZE: dense_size
                }
        
                run_name = 'run-%d' %session_num
                print('---- Starting trial : %s' % run_name)
                print({h.name: hparams[h] for h in hparams})
                run('D:/sam/Logs/Model 4/hparam_tuning/' +run_name, hparams, session_num)
        
                session_num += 1
# Out:
# ---- Starting trial : run-1
# {'filter_size': 5, 'filters_number': 64, 'filter_size_2': 3, 'dense_size': 512}
# Epoch 1/15
# 63/63 - 49s - loss: 1.3557 - accuracy: 0.4720 - val_loss: 0.9992 - val_accuracy: 0.6200
# Epoch 2/15
# 63/63 - 47s - loss: 0.8803 - accuracy: 0.6301 - val_loss: 1.0407 - val_accuracy: 0.5720
# Epoch 3/15
# 63/63 - 45s - loss: 0.7867 - accuracy: 0.6873 - val_loss: 0.9162 - val_accuracy: 0.5920
# Epoch 4/15
# 63/63 - 45s - loss: 0.7352 - accuracy: 0.7025 - val_loss: 0.8799 - val_accuracy: 0.6420
# Epoch 5/15
# 63/63 - 47s - loss: 0.6705 - accuracy: 0.7295 - val_loss: 0.9459 - val_accuracy: 0.6540
# Epoch 6/15
# 63/63 - 47s - loss: 0.6425 - accuracy: 0.7428 - val_loss: 0.7365 - val_accuracy: 0.7120
# Epoch 7/15
# 63/63 - 46s - loss: 0.5598 - accuracy: 0.7787 - val_loss: 0.7142 - val_accuracy: 0.7320
# Epoch 8/15
# 63/63 - 48s - loss: 0.5101 - accuracy: 0.8027 - val_loss: 0.6664 - val_accuracy: 0.7400
# Epoch 9/15
# 63/63 - 47s - loss: 0.4758 - accuracy: 0.8129 - val_loss: 0.6848 - val_accuracy: 0.7440
# Epoch 10/15
# 63/63 - 49s - loss: 0.4421 - accuracy: 0.8224 - val_loss: 0.7390 - val_accuracy: 0.7360
# 16/16 [==============================] - 1s 82ms/step - loss: 0.6664 - accuracy: 0.7400
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 4/Run-1\assets
# ---- Starting trial : run-2
# {'filter_size': 5, 'filters_number': 64, 'filter_size_2': 3, 'dense_size': 1024}
# Epoch 1/15
# 63/63 - 54s - loss: 1.4515 - accuracy: 0.5212 - val_loss: 1.0908 - val_accuracy: 0.5120
# Epoch 2/15
# 63/63 - 52s - loss: 0.8787 - accuracy: 0.6371 - val_loss: 0.9367 - val_accuracy: 0.5740
# Epoch 3/15
# 63/63 - 54s - loss: 0.7882 - accuracy: 0.6751 - val_loss: 0.9643 - val_accuracy: 0.6540
# Epoch 4/15
# 63/63 - 52s - loss: 0.7616 - accuracy: 0.6986 - val_loss: 1.0029 - val_accuracy: 0.6100
# 16/16 [==============================] - 2s 93ms/step - loss: 0.9367 - accuracy: 0.5740
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 4/Run-2\assets
# ---- Starting trial : run-3
# {'filter_size': 5, 'filters_number': 64, 'filter_size_2': 5, 'dense_size': 512}
# Epoch 1/15
# 63/63 - 68s - loss: 1.2457 - accuracy: 0.5045 - val_loss: 0.9955 - val_accuracy: 0.6300
# Epoch 2/15
# 63/63 - 66s - loss: 0.8971 - accuracy: 0.6351 - val_loss: 1.0659 - val_accuracy: 0.5680
# Epoch 3/15
# 63/63 - 64s - loss: 0.7748 - accuracy: 0.6846 - val_loss: 0.8924 - val_accuracy: 0.6420
# Epoch 4/15
# 63/63 - 65s - loss: 0.7506 - accuracy: 0.7018 - val_loss: 0.8421 - val_accuracy: 0.6780
# Epoch 5/15
# 63/63 - 63s - loss: 0.6652 - accuracy: 0.7318 - val_loss: 0.7843 - val_accuracy: 0.6840
# Epoch 6/15
# 63/63 - 65s - loss: 0.6028 - accuracy: 0.7622 - val_loss: 0.7702 - val_accuracy: 0.6780
# Epoch 7/15
# 63/63 - 63s - loss: 0.5616 - accuracy: 0.7667 - val_loss: 0.7447 - val_accuracy: 0.7120
# Epoch 8/15
# 63/63 - 64s - loss: 0.5207 - accuracy: 0.7905 - val_loss: 0.7887 - val_accuracy: 0.7140
# Epoch 9/15
# 63/63 - 66s - loss: 0.4851 - accuracy: 0.8087 - val_loss: 0.7148 - val_accuracy: 0.7580
# Epoch 10/15
# 63/63 - 66s - loss: 0.4326 - accuracy: 0.8287 - val_loss: 0.6888 - val_accuracy: 0.7600
# Epoch 11/15
# 63/63 - 67s - loss: 0.3923 - accuracy: 0.8511 - val_loss: 0.6996 - val_accuracy: 0.7500
# Epoch 12/15
# 63/63 - 70s - loss: 0.3971 - accuracy: 0.8422 - val_loss: 0.7513 - val_accuracy: 0.7300
# 16/16 [==============================] - 2s 124ms/step - loss: 0.6888 - accuracy: 0.7600
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 4/Run-3\assets
# ---- Starting trial : run-4
# {'filter_size': 5, 'filters_number': 64, 'filter_size_2': 5, 'dense_size': 1024}
# Epoch 1/15
# 63/63 - 76s - loss: 1.5048 - accuracy: 0.4743 - val_loss: 1.1382 - val_accuracy: 0.5300
# Epoch 2/15
# 63/63 - 71s - loss: 0.9049 - accuracy: 0.6354 - val_loss: 1.0466 - val_accuracy: 0.5900
# Epoch 3/15
# 63/63 - 76s - loss: 0.7872 - accuracy: 0.6788 - val_loss: 0.9138 - val_accuracy: 0.6040
# Epoch 4/15
# 63/63 - 77s - loss: 0.7112 - accuracy: 0.7110 - val_loss: 0.8059 - val_accuracy: 0.6700
# Epoch 5/15
# 63/63 - 71s - loss: 0.6686 - accuracy: 0.7253 - val_loss: 0.7796 - val_accuracy: 0.6920
# Epoch 6/15
# 63/63 - 69s - loss: 0.5822 - accuracy: 0.7740 - val_loss: 0.7542 - val_accuracy: 0.7120
# Epoch 7/15
# 63/63 - 68s - loss: 0.5364 - accuracy: 0.7887 - val_loss: 0.7331 - val_accuracy: 0.7200
# Epoch 8/15
# 63/63 - 69s - loss: 0.5171 - accuracy: 0.7852 - val_loss: 0.7084 - val_accuracy: 0.7180
# Epoch 9/15
# 63/63 - 68s - loss: 0.4742 - accuracy: 0.8082 - val_loss: 0.7051 - val_accuracy: 0.7300
# Epoch 10/15
# 63/63 - 69s - loss: 0.4178 - accuracy: 0.8357 - val_loss: 0.7719 - val_accuracy: 0.7420
# Epoch 11/15
# 63/63 - 68s - loss: 0.4036 - accuracy: 0.8359 - val_loss: 0.7429 - val_accuracy: 0.7280
# 16/16 [==============================] - 2s 119ms/step - loss: 0.7051 - accuracy: 0.7300
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 4/Run-4\assets
# ---- Starting trial : run-5
# {'filter_size': 5, 'filters_number': 96, 'filter_size_2': 3, 'dense_size': 512}
# Epoch 1/15
# 63/63 - 73s - loss: 1.4932 - accuracy: 0.5050 - val_loss: 1.0008 - val_accuracy: 0.6080
# Epoch 2/15
# 63/63 - 71s - loss: 0.8693 - accuracy: 0.6446 - val_loss: 1.0190 - val_accuracy: 0.5920
# Epoch 3/15
# 63/63 - 78s - loss: 0.7740 - accuracy: 0.6863 - val_loss: 0.8935 - val_accuracy: 0.6340
# Epoch 4/15
# 63/63 - 85s - loss: 0.7044 - accuracy: 0.7100 - val_loss: 0.9157 - val_accuracy: 0.6540
# Epoch 5/15
# 63/63 - 70s - loss: 0.6335 - accuracy: 0.7430 - val_loss: 0.8036 - val_accuracy: 0.6700
# Epoch 6/15
# 63/63 - 68s - loss: 0.5742 - accuracy: 0.7717 - val_loss: 0.7739 - val_accuracy: 0.6800
# Epoch 7/15
# 63/63 - 74s - loss: 0.5717 - accuracy: 0.7650 - val_loss: 0.7452 - val_accuracy: 0.7020
# Epoch 8/15
# 63/63 - 74s - loss: 0.5150 - accuracy: 0.7922 - val_loss: 0.7507 - val_accuracy: 0.7200
# Epoch 9/15
# 63/63 - 79s - loss: 0.4695 - accuracy: 0.8129 - val_loss: 0.7339 - val_accuracy: 0.7180
# Epoch 10/15
# 63/63 - 72s - loss: 0.4121 - accuracy: 0.8394 - val_loss: 0.8257 - val_accuracy: 0.7300
# Epoch 11/15
# 63/63 - 69s - loss: 0.3674 - accuracy: 0.8581 - val_loss: 0.7655 - val_accuracy: 0.7600
# 16/16 [==============================] - 2s 124ms/step - loss: 0.7339 - accuracy: 0.7180
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 4/Run-5\assets
# ---- Starting trial : run-6
# {'filter_size': 5, 'filters_number': 96, 'filter_size_2': 3, 'dense_size': 1024}
# Epoch 1/15
# 63/63 - 86s - loss: 1.4315 - accuracy: 0.4940 - val_loss: 1.0088 - val_accuracy: 0.5720
# Epoch 2/15
# 63/63 - 79s - loss: 0.9290 - accuracy: 0.6209 - val_loss: 0.9350 - val_accuracy: 0.6340
# Epoch 3/15
# 63/63 - 85s - loss: 0.8663 - accuracy: 0.6444 - val_loss: 0.9667 - val_accuracy: 0.5960
# Epoch 4/15
# 63/63 - 82s - loss: 0.7435 - accuracy: 0.6958 - val_loss: 0.8990 - val_accuracy: 0.6280
# Epoch 5/15
# 63/63 - 83s - loss: 0.6786 - accuracy: 0.7223 - val_loss: 0.8363 - val_accuracy: 0.6580
# Epoch 6/15
# 63/63 - 81s - loss: 0.6560 - accuracy: 0.7375 - val_loss: 0.7937 - val_accuracy: 0.6660
# Epoch 7/15
# 63/63 - 79s - loss: 0.6169 - accuracy: 0.7475 - val_loss: 0.7543 - val_accuracy: 0.6860
# Epoch 8/15
# 63/63 - 84s - loss: 0.5530 - accuracy: 0.7722 - val_loss: 0.7536 - val_accuracy: 0.7060
# Epoch 9/15
# 63/63 - 81s - loss: 0.5064 - accuracy: 0.7935 - val_loss: 0.7332 - val_accuracy: 0.7180
# Epoch 10/15
# 63/63 - 83s - loss: 0.4942 - accuracy: 0.7962 - val_loss: 0.7382 - val_accuracy: 0.7340
# Epoch 11/15
# 63/63 - 78s - loss: 0.4686 - accuracy: 0.8087 - val_loss: 0.7879 - val_accuracy: 0.7240
# 16/16 [==============================] - 2s 142ms/step - loss: 0.7332 - accuracy: 0.7180
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 4/Run-6\assets
# ---- Starting trial : run-7
# {'filter_size': 5, 'filters_number': 96, 'filter_size_2': 5, 'dense_size': 512}
# Epoch 1/15
# 63/63 - 110s - loss: 1.4680 - accuracy: 0.4880 - val_loss: 1.0448 - val_accuracy: 0.5600
# Epoch 2/15
# 63/63 - 104s - loss: 0.8924 - accuracy: 0.6346 - val_loss: 0.9480 - val_accuracy: 0.6260
# Epoch 3/15
# 63/63 - 106s - loss: 0.7862 - accuracy: 0.6808 - val_loss: 0.8757 - val_accuracy: 0.6780
# Epoch 4/15
# 63/63 - 102s - loss: 0.7320 - accuracy: 0.7105 - val_loss: 0.8004 - val_accuracy: 0.6860
# Epoch 5/15
# 63/63 - 115s - loss: 0.6820 - accuracy: 0.7285 - val_loss: 0.8510 - val_accuracy: 0.6460
# Epoch 6/15
# 63/63 - 113s - loss: 0.6319 - accuracy: 0.7450 - val_loss: 0.7899 - val_accuracy: 0.6800
# Epoch 7/15
# 63/63 - 100s - loss: 0.5971 - accuracy: 0.7585 - val_loss: 0.7779 - val_accuracy: 0.6660
# Epoch 8/15
# 63/63 - 103s - loss: 0.5591 - accuracy: 0.7742 - val_loss: 0.7996 - val_accuracy: 0.6960
# Epoch 9/15
# 63/63 - 103s - loss: 0.5289 - accuracy: 0.7835 - val_loss: 0.7434 - val_accuracy: 0.7120
# Epoch 10/15
# 63/63 - 100s - loss: 0.4766 - accuracy: 0.7967 - val_loss: 0.6868 - val_accuracy: 0.7500
# Epoch 11/15
# 63/63 - 100s - loss: 0.4440 - accuracy: 0.8234 - val_loss: 0.7680 - val_accuracy: 0.7120
# Epoch 12/15
# 63/63 - 105s - loss: 0.4012 - accuracy: 0.8427 - val_loss: 0.7263 - val_accuracy: 0.7440
# 16/16 [==============================] - 3s 197ms/step - loss: 0.6868 - accuracy: 0.7500
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 4/Run-7\assets
# ---- Starting trial : run-8
# {'filter_size': 5, 'filters_number': 96, 'filter_size_2': 5, 'dense_size': 1024}
# Epoch 1/15
# 63/63 - 116s - loss: 1.6307 - accuracy: 0.4241 - val_loss: 1.1825 - val_accuracy: 0.4520
# Epoch 2/15
# 63/63 - 109s - loss: 1.0182 - accuracy: 0.5644 - val_loss: 0.9731 - val_accuracy: 0.6080
# Epoch 3/15
# 63/63 - 110s - loss: 0.8636 - accuracy: 0.6389 - val_loss: 0.9864 - val_accuracy: 0.5680
# Epoch 4/15
# 63/63 - 112s - loss: 0.8416 - accuracy: 0.6454 - val_loss: 1.1364 - val_accuracy: 0.5780
# 16/16 [==============================] - 3s 199ms/step - loss: 0.9731 - accuracy: 0.6080
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 4/Run-8\assets
# ---- Starting trial : run-9
# {'filter_size': 5, 'filters_number': 128, 'filter_size_2': 3, 'dense_size': 512}
# Epoch 1/15
# 63/63 - 108s - loss: 1.4973 - accuracy: 0.4578 - val_loss: 1.0325 - val_accuracy: 0.5640
# Epoch 2/15
# 63/63 - 113s - loss: 0.8801 - accuracy: 0.6406 - val_loss: 0.9358 - val_accuracy: 0.6040
# Epoch 3/15
# 63/63 - 114s - loss: 0.7688 - accuracy: 0.6878 - val_loss: 0.9045 - val_accuracy: 0.6460
# Epoch 4/15
# 63/63 - 109s - loss: 0.7190 - accuracy: 0.6998 - val_loss: 0.8088 - val_accuracy: 0.6960
# Epoch 5/15
# 63/63 - 106s - loss: 0.6393 - accuracy: 0.7418 - val_loss: 0.7636 - val_accuracy: 0.6960
# Epoch 6/15
# 63/63 - 109s - loss: 0.6096 - accuracy: 0.7577 - val_loss: 0.7954 - val_accuracy: 0.6880
# Epoch 7/15
# 63/63 - 100s - loss: 0.5359 - accuracy: 0.7852 - val_loss: 0.7466 - val_accuracy: 0.7180
# Epoch 8/15
# 63/63 - 101s - loss: 0.4991 - accuracy: 0.7987 - val_loss: 0.7553 - val_accuracy: 0.7280
# Epoch 9/15
# 63/63 - 104s - loss: 0.4527 - accuracy: 0.8177 - val_loss: 0.7219 - val_accuracy: 0.7280
# Epoch 10/15
# 63/63 - 107s - loss: 0.4547 - accuracy: 0.8249 - val_loss: 0.7406 - val_accuracy: 0.7320
# Epoch 11/15
# 63/63 - 106s - loss: 0.5065 - accuracy: 0.7955 - val_loss: 0.7371 - val_accuracy: 0.7240
# 16/16 [==============================] - 3s 200ms/step - loss: 0.7219 - accuracy: 0.7280
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 4/Run-9\assets
# ---- Starting trial : run-10
# {'filter_size': 5, 'filters_number': 128, 'filter_size_2': 3, 'dense_size': 1024}
# Epoch 1/15
# 63/63 - 121s - loss: 1.7839 - accuracy: 0.4525 - val_loss: 1.1957 - val_accuracy: 0.4540
# Epoch 2/15
# 63/63 - 120s - loss: 0.9350 - accuracy: 0.6169 - val_loss: 0.9261 - val_accuracy: 0.6300
# Epoch 3/15
# 63/63 - 117s - loss: 0.8221 - accuracy: 0.6596 - val_loss: 0.9131 - val_accuracy: 0.6180
# Epoch 4/15
# 63/63 - 120s - loss: 0.7257 - accuracy: 0.7035 - val_loss: 0.8713 - val_accuracy: 0.6360
# Epoch 5/15
# 63/63 - 122s - loss: 0.6867 - accuracy: 0.7218 - val_loss: 0.8078 - val_accuracy: 0.6880
# Epoch 6/15
# 63/63 - 117s - loss: 0.6146 - accuracy: 0.7562 - val_loss: 0.8923 - val_accuracy: 0.6200
# Epoch 7/15
# 63/63 - 121s - loss: 0.5607 - accuracy: 0.7700 - val_loss: 0.8008 - val_accuracy: 0.6980
# Epoch 8/15
# 63/63 - 112s - loss: 0.5326 - accuracy: 0.7770 - val_loss: 0.7501 - val_accuracy: 0.7080
# Epoch 9/15
# 63/63 - 110s - loss: 0.6036 - accuracy: 0.7572 - val_loss: 0.8323 - val_accuracy: 0.6980
# Epoch 10/15
# 63/63 - 110s - loss: 0.4708 - accuracy: 0.8104 - val_loss: 0.7237 - val_accuracy: 0.7300
# Epoch 11/15
# 63/63 - 110s - loss: 0.4225 - accuracy: 0.8379 - val_loss: 0.7239 - val_accuracy: 0.7340
# Epoch 12/15
# 63/63 - 109s - loss: 0.3988 - accuracy: 0.8427 - val_loss: 0.8668 - val_accuracy: 0.6980
# 16/16 [==============================] - 3s 208ms/step - loss: 0.7237 - accuracy: 0.7300
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 4/Run-10\assets
# ---- Starting trial : run-11
# {'filter_size': 5, 'filters_number': 128, 'filter_size_2': 5, 'dense_size': 512}
# Epoch 1/15
# 63/63 - 151s - loss: 1.7200 - accuracy: 0.4870 - val_loss: 1.0765 - val_accuracy: 0.5020
# Epoch 2/15
# 63/63 - 149s - loss: 0.8742 - accuracy: 0.6419 - val_loss: 0.9117 - val_accuracy: 0.6520
# Epoch 3/15
# 63/63 - 148s - loss: 0.7732 - accuracy: 0.6783 - val_loss: 0.9310 - val_accuracy: 0.6340
# Epoch 4/15
# 63/63 - 152s - loss: 0.7424 - accuracy: 0.7028 - val_loss: 0.8773 - val_accuracy: 0.6640
# Epoch 5/15
# 63/63 - 148s - loss: 0.6941 - accuracy: 0.7153 - val_loss: 0.8196 - val_accuracy: 0.6720
# Epoch 6/15
# 63/63 - 149s - loss: 0.6221 - accuracy: 0.7403 - val_loss: 0.8080 - val_accuracy: 0.6980
# Epoch 7/15
# 63/63 - 148s - loss: 0.5732 - accuracy: 0.7670 - val_loss: 0.7368 - val_accuracy: 0.7040
# Epoch 8/15
# 63/63 - 148s - loss: 0.5324 - accuracy: 0.7842 - val_loss: 0.7522 - val_accuracy: 0.7200
# Epoch 9/15
# 63/63 - 148s - loss: 0.5160 - accuracy: 0.7847 - val_loss: 0.7789 - val_accuracy: 0.7160
# 16/16 [==============================] - 5s 294ms/step - loss: 0.7368 - accuracy: 0.7040
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 4/Run-11\assets
# ---- Starting trial : run-12
# {'filter_size': 5, 'filters_number': 128, 'filter_size_2': 5, 'dense_size': 1024}
# Epoch 1/15
# 63/63 - 166s - loss: 1.6633 - accuracy: 0.4805 - val_loss: 1.0454 - val_accuracy: 0.5780
# Epoch 2/15
# 63/63 - 161s - loss: 1.0078 - accuracy: 0.5889 - val_loss: 0.9809 - val_accuracy: 0.5940
# Epoch 3/15
# 63/63 - 161s - loss: 0.9603 - accuracy: 0.6056 - val_loss: 0.9457 - val_accuracy: 0.6020
# Epoch 4/15
# 63/63 - 164s - loss: 0.7994 - accuracy: 0.6716 - val_loss: 0.8554 - val_accuracy: 0.6320
# Epoch 5/15
# 63/63 - 164s - loss: 0.7037 - accuracy: 0.7088 - val_loss: 0.8743 - val_accuracy: 0.6500
# Epoch 6/15
# 63/63 - 166s - loss: 0.7142 - accuracy: 0.6973 - val_loss: 0.8239 - val_accuracy: 0.6580
# Epoch 7/15
# 63/63 - 169s - loss: 0.6176 - accuracy: 0.7420 - val_loss: 0.7718 - val_accuracy: 0.7140
# Epoch 8/15
# 63/63 - 173s - loss: 0.6079 - accuracy: 0.7458 - val_loss: 0.7560 - val_accuracy: 0.6820
# Epoch 9/15
# 63/63 - 165s - loss: 0.5494 - accuracy: 0.7715 - val_loss: 0.7386 - val_accuracy: 0.7240
# Epoch 10/15
# 63/63 - 164s - loss: 0.5433 - accuracy: 0.7732 - val_loss: 0.7253 - val_accuracy: 0.7380
# Epoch 11/15
# 63/63 - 164s - loss: 0.4751 - accuracy: 0.8037 - val_loss: 0.7464 - val_accuracy: 0.7100
# Epoch 12/15
# 63/63 - 166s - loss: 0.4469 - accuracy: 0.8169 - val_loss: 0.7113 - val_accuracy: 0.7180
# Epoch 13/15
# 63/63 - 170s - loss: 0.4064 - accuracy: 0.8377 - val_loss: 0.7381 - val_accuracy: 0.7140
# Epoch 14/15
# 63/63 - 180s - loss: 0.3738 - accuracy: 0.8534 - val_loss: 0.7224 - val_accuracy: 0.7240
# 16/16 [==============================] - 5s 315ms/step - loss: 0.7113 - accuracy: 0.7180
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 4/Run-12\assets
# ---- Starting trial : run-13
# {'filter_size': 7, 'filters_number': 64, 'filter_size_2': 3, 'dense_size': 512}
# Epoch 1/15
# 63/63 - 53s - loss: 1.3834 - accuracy: 0.4510 - val_loss: 1.2369 - val_accuracy: 0.4300
# Epoch 2/15
# 63/63 - 52s - loss: 0.9509 - accuracy: 0.6044 - val_loss: 0.9545 - val_accuracy: 0.5920
# Epoch 3/15
# 63/63 - 51s - loss: 0.8175 - accuracy: 0.6646 - val_loss: 0.8699 - val_accuracy: 0.6500
# Epoch 4/15
# 63/63 - 53s - loss: 0.7378 - accuracy: 0.6938 - val_loss: 0.8206 - val_accuracy: 0.6600
# Epoch 5/15
# 63/63 - 52s - loss: 0.6932 - accuracy: 0.7235 - val_loss: 0.8138 - val_accuracy: 0.6700
# Epoch 6/15
# 63/63 - 50s - loss: 0.6644 - accuracy: 0.7265 - val_loss: 0.8088 - val_accuracy: 0.6720
# Epoch 7/15
# 63/63 - 54s - loss: 0.6034 - accuracy: 0.7510 - val_loss: 0.7450 - val_accuracy: 0.7200
# Epoch 8/15
# 63/63 - 57s - loss: 0.5630 - accuracy: 0.7710 - val_loss: 0.8053 - val_accuracy: 0.7120
# Epoch 9/15
# 63/63 - 59s - loss: 0.5341 - accuracy: 0.7860 - val_loss: 0.7157 - val_accuracy: 0.7080
# Epoch 10/15
# 63/63 - 54s - loss: 0.5273 - accuracy: 0.7867 - val_loss: 0.8199 - val_accuracy: 0.6740
# Epoch 11/15
# 63/63 - 56s - loss: 0.4736 - accuracy: 0.8042 - val_loss: 0.7329 - val_accuracy: 0.7260
# 16/16 [==============================] - 2s 99ms/step - loss: 0.7157 - accuracy: 0.7080
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 4/Run-13\assets
# ---- Starting trial : run-14
# {'filter_size': 7, 'filters_number': 64, 'filter_size_2': 3, 'dense_size': 1024}
# Epoch 1/15
# 63/63 - 70s - loss: 1.4511 - accuracy: 0.4638 - val_loss: 1.0641 - val_accuracy: 0.5900
# Epoch 2/15
# 63/63 - 60s - loss: 0.9726 - accuracy: 0.6031 - val_loss: 1.0019 - val_accuracy: 0.6040
# Epoch 3/15
# 63/63 - 61s - loss: 0.8739 - accuracy: 0.6404 - val_loss: 0.9257 - val_accuracy: 0.6580
# Epoch 4/15
# 63/63 - 59s - loss: 0.7842 - accuracy: 0.6886 - val_loss: 0.8628 - val_accuracy: 0.6420
# Epoch 5/15
# 63/63 - 64s - loss: 0.7443 - accuracy: 0.6928 - val_loss: 0.8402 - val_accuracy: 0.6760
# Epoch 6/15
# 63/63 - 67s - loss: 0.6870 - accuracy: 0.7195 - val_loss: 0.9164 - val_accuracy: 0.6380
# Epoch 7/15
# 63/63 - 65s - loss: 0.6852 - accuracy: 0.7168 - val_loss: 0.8313 - val_accuracy: 0.6640
# Epoch 8/15
# 63/63 - 62s - loss: 0.6265 - accuracy: 0.7413 - val_loss: 0.8700 - val_accuracy: 0.6540
# Epoch 9/15
# 63/63 - 64s - loss: 0.5660 - accuracy: 0.7670 - val_loss: 0.7835 - val_accuracy: 0.7140
# Epoch 10/15
# 63/63 - 67s - loss: 0.5648 - accuracy: 0.7655 - val_loss: 0.7720 - val_accuracy: 0.7200
# Epoch 11/15
# 63/63 - 61s - loss: 0.5099 - accuracy: 0.7930 - val_loss: 0.7941 - val_accuracy: 0.6880
# Epoch 12/15
# 63/63 - 65s - loss: 0.4580 - accuracy: 0.8197 - val_loss: 0.8983 - val_accuracy: 0.6760
# 16/16 [==============================] - 2s 104ms/step - loss: 0.7720 - accuracy: 0.7200
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 4/Run-14\assets
# ---- Starting trial : run-15
# {'filter_size': 7, 'filters_number': 64, 'filter_size_2': 5, 'dense_size': 512}
# Epoch 1/15
# 63/63 - 73s - loss: 1.4707 - accuracy: 0.4488 - val_loss: 1.0410 - val_accuracy: 0.5760
# Epoch 2/15
# 63/63 - 71s - loss: 0.9282 - accuracy: 0.6206 - val_loss: 0.9586 - val_accuracy: 0.6140
# Epoch 3/15
# 63/63 - 71s - loss: 0.8317 - accuracy: 0.6663 - val_loss: 0.8918 - val_accuracy: 0.6500
# Epoch 4/15
# 63/63 - 69s - loss: 0.7547 - accuracy: 0.6911 - val_loss: 0.8380 - val_accuracy: 0.6580
# Epoch 5/15
# 63/63 - 66s - loss: 0.7188 - accuracy: 0.7100 - val_loss: 0.9155 - val_accuracy: 0.6020
# Epoch 6/15
# 63/63 - 67s - loss: 0.6788 - accuracy: 0.7198 - val_loss: 0.8323 - val_accuracy: 0.6540
# Epoch 7/15
# 63/63 - 66s - loss: 0.6304 - accuracy: 0.7478 - val_loss: 0.8477 - val_accuracy: 0.6820
# Epoch 8/15
# 63/63 - 65s - loss: 0.6529 - accuracy: 0.7285 - val_loss: 0.8276 - val_accuracy: 0.6560
# Epoch 9/15
# 63/63 - 65s - loss: 0.5730 - accuracy: 0.7642 - val_loss: 0.7582 - val_accuracy: 0.7060
# Epoch 10/15
# 63/63 - 68s - loss: 0.5029 - accuracy: 0.7995 - val_loss: 0.7375 - val_accuracy: 0.7100
# Epoch 11/15
# 63/63 - 69s - loss: 0.4835 - accuracy: 0.8049 - val_loss: 0.7890 - val_accuracy: 0.7200
# Epoch 12/15
# 63/63 - 76s - loss: 0.4429 - accuracy: 0.8274 - val_loss: 0.7800 - val_accuracy: 0.6960
# 16/16 [==============================] - 2s 129ms/step - loss: 0.7375 - accuracy: 0.7100
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 4/Run-15\assets
# ---- Starting trial : run-16
# {'filter_size': 7, 'filters_number': 64, 'filter_size_2': 5, 'dense_size': 1024}
# Epoch 1/15
# 63/63 - 91s - loss: 1.6211 - accuracy: 0.3981 - val_loss: 1.2541 - val_accuracy: 0.4480
# Epoch 2/15
# 63/63 - 81s - loss: 1.0926 - accuracy: 0.5292 - val_loss: 1.0387 - val_accuracy: 0.5620
# Epoch 3/15
# 63/63 - 84s - loss: 0.9405 - accuracy: 0.6059 - val_loss: 0.9840 - val_accuracy: 0.5920
# Epoch 4/15
# 63/63 - 83s - loss: 0.8540 - accuracy: 0.6469 - val_loss: 0.9006 - val_accuracy: 0.6480
# Epoch 5/15
# 63/63 - 83s - loss: 0.8119 - accuracy: 0.6658 - val_loss: 0.9038 - val_accuracy: 0.6600
# Epoch 6/15
# 63/63 - 78s - loss: 0.7592 - accuracy: 0.6831 - val_loss: 0.8856 - val_accuracy: 0.6500
# Epoch 7/15
# 63/63 - 82s - loss: 0.7405 - accuracy: 0.6888 - val_loss: 0.8944 - val_accuracy: 0.6360
# Epoch 8/15
# 63/63 - 84s - loss: 0.7135 - accuracy: 0.6973 - val_loss: 0.8939 - val_accuracy: 0.6580
# 16/16 [==============================] - 2s 129ms/step - loss: 0.8856 - accuracy: 0.6500
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 4/Run-16\assets
# ---- Starting trial : run-17
# {'filter_size': 7, 'filters_number': 96, 'filter_size_2': 3, 'dense_size': 512}
# Epoch 1/15
# 63/63 - 87s - loss: 1.6107 - accuracy: 0.4823 - val_loss: 1.0906 - val_accuracy: 0.5580
# Epoch 2/15
# 63/63 - 81s - loss: 1.0024 - accuracy: 0.5842 - val_loss: 1.0362 - val_accuracy: 0.5600
# Epoch 3/15
# 63/63 - 77s - loss: 0.8719 - accuracy: 0.6336 - val_loss: 0.9685 - val_accuracy: 0.6000
# Epoch 4/15
# 63/63 - 76s - loss: 0.7842 - accuracy: 0.6811 - val_loss: 0.9301 - val_accuracy: 0.6200
# Epoch 5/15
# 63/63 - 76s - loss: 0.7766 - accuracy: 0.6791 - val_loss: 0.9067 - val_accuracy: 0.6160
# Epoch 6/15
# 63/63 - 74s - loss: 0.7121 - accuracy: 0.7148 - val_loss: 0.8818 - val_accuracy: 0.6460
# Epoch 7/15
# 63/63 - 73s - loss: 0.6517 - accuracy: 0.7323 - val_loss: 0.8353 - val_accuracy: 0.6960
# Epoch 8/15
# 63/63 - 74s - loss: 0.6190 - accuracy: 0.7540 - val_loss: 0.7845 - val_accuracy: 0.6920
# Epoch 9/15
# 63/63 - 77s - loss: 0.5619 - accuracy: 0.7727 - val_loss: 0.8530 - val_accuracy: 0.7000
# Epoch 10/15
# 63/63 - 79s - loss: 0.5490 - accuracy: 0.7850 - val_loss: 0.8256 - val_accuracy: 0.7260
# 16/16 [==============================] - 2s 137ms/step - loss: 0.7845 - accuracy: 0.6920
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 4/Run-17\assets
# ---- Starting trial : run-18
# {'filter_size': 7, 'filters_number': 96, 'filter_size_2': 3, 'dense_size': 1024}
# Epoch 1/15
# 63/63 - 86s - loss: 1.4788 - accuracy: 0.4426 - val_loss: 1.2703 - val_accuracy: 0.5020
# Epoch 2/15
# 63/63 - 84s - loss: 0.9643 - accuracy: 0.6056 - val_loss: 1.0023 - val_accuracy: 0.6160
# Epoch 3/15
# 63/63 - 84s - loss: 0.9093 - accuracy: 0.6414 - val_loss: 0.9575 - val_accuracy: 0.6140
# Epoch 4/15
# 63/63 - 82s - loss: 0.8322 - accuracy: 0.6636 - val_loss: 0.9065 - val_accuracy: 0.6240
# Epoch 5/15
# 63/63 - 84s - loss: 0.7538 - accuracy: 0.6888 - val_loss: 0.8764 - val_accuracy: 0.6500
# Epoch 6/15
# 63/63 - 83s - loss: 0.7370 - accuracy: 0.6991 - val_loss: 0.7983 - val_accuracy: 0.6940
# Epoch 7/15
# 63/63 - 87s - loss: 0.6839 - accuracy: 0.7233 - val_loss: 0.9766 - val_accuracy: 0.6120
# Epoch 8/15
# 63/63 - 85s - loss: 0.6485 - accuracy: 0.7278 - val_loss: 0.8004 - val_accuracy: 0.6720
# 16/16 [==============================] - 2s 147ms/step - loss: 0.7983 - accuracy: 0.6940
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 4/Run-18\assets
# ---- Starting trial : run-19
# {'filter_size': 7, 'filters_number': 96, 'filter_size_2': 5, 'dense_size': 512}
# Epoch 1/15
# 63/63 - 107s - loss: 1.5943 - accuracy: 0.4088 - val_loss: 1.2518 - val_accuracy: 0.4360
# Epoch 2/15
# 63/63 - 105s - loss: 0.9988 - accuracy: 0.5732 - val_loss: 0.9625 - val_accuracy: 0.5920
# Epoch 3/15
# 63/63 - 105s - loss: 0.8399 - accuracy: 0.6551 - val_loss: 0.9474 - val_accuracy: 0.5860
# Epoch 4/15
# 63/63 - 105s - loss: 0.7767 - accuracy: 0.6811 - val_loss: 0.8423 - val_accuracy: 0.6620
# Epoch 5/15
# 63/63 - 105s - loss: 0.7279 - accuracy: 0.7010 - val_loss: 0.8257 - val_accuracy: 0.6720
# Epoch 6/15
# 63/63 - 108s - loss: 0.6957 - accuracy: 0.7168 - val_loss: 0.7989 - val_accuracy: 0.6820
# Epoch 7/15
# 63/63 - 104s - loss: 0.6567 - accuracy: 0.7348 - val_loss: 0.7817 - val_accuracy: 0.7020
# Epoch 8/15
# 63/63 - 105s - loss: 0.6142 - accuracy: 0.7483 - val_loss: 0.7541 - val_accuracy: 0.7020
# Epoch 9/15
# 63/63 - 104s - loss: 0.5706 - accuracy: 0.7780 - val_loss: 0.7069 - val_accuracy: 0.7140
# Epoch 10/15
# 63/63 - 105s - loss: 0.5279 - accuracy: 0.7865 - val_loss: 0.8410 - val_accuracy: 0.6560
# Epoch 11/15
# 63/63 - 105s - loss: 0.5184 - accuracy: 0.7870 - val_loss: 0.7081 - val_accuracy: 0.7260
# 16/16 [==============================] - 3s 202ms/step - loss: 0.7069 - accuracy: 0.7140
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 4/Run-19\assets
# ---- Starting trial : run-20
# {'filter_size': 7, 'filters_number': 96, 'filter_size_2': 5, 'dense_size': 1024}
# Epoch 1/15
# 63/63 - 115s - loss: 1.7965 - accuracy: 0.4118 - val_loss: 1.1203 - val_accuracy: 0.5080
# Epoch 2/15
# 63/63 - 114s - loss: 1.0018 - accuracy: 0.5902 - val_loss: 1.0272 - val_accuracy: 0.5580
# Epoch 3/15
# 63/63 - 112s - loss: 0.8898 - accuracy: 0.6361 - val_loss: 0.9441 - val_accuracy: 0.6140
# Epoch 4/15
# 63/63 - 114s - loss: 0.8161 - accuracy: 0.6646 - val_loss: 0.9218 - val_accuracy: 0.6280
# Epoch 5/15
# 63/63 - 113s - loss: 0.7727 - accuracy: 0.6778 - val_loss: 0.9180 - val_accuracy: 0.6220
# Epoch 6/15
# 63/63 - 113s - loss: 0.7194 - accuracy: 0.7075 - val_loss: 0.8183 - val_accuracy: 0.6820
# Epoch 7/15
# 63/63 - 112s - loss: 0.6605 - accuracy: 0.7333 - val_loss: 0.8427 - val_accuracy: 0.6680
# Epoch 8/15
# 63/63 - 113s - loss: 0.6471 - accuracy: 0.7425 - val_loss: 0.8435 - val_accuracy: 0.6800
# 16/16 [==============================] - 3s 206ms/step - loss: 0.8183 - accuracy: 0.6820
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 4/Run-20\assets
# ---- Starting trial : run-21
# {'filter_size': 7, 'filters_number': 128, 'filter_size_2': 3, 'dense_size': 512}
# Epoch 1/15
# 63/63 - 108s - loss: 1.8585 - accuracy: 0.4311 - val_loss: 1.0880 - val_accuracy: 0.5540
# Epoch 2/15
# 63/63 - 107s - loss: 0.9614 - accuracy: 0.5994 - val_loss: 1.0060 - val_accuracy: 0.5940
# Epoch 3/15
# 63/63 - 107s - loss: 0.8846 - accuracy: 0.6419 - val_loss: 0.9089 - val_accuracy: 0.6620
# Epoch 4/15
# 63/63 - 107s - loss: 0.8133 - accuracy: 0.6693 - val_loss: 0.9310 - val_accuracy: 0.6140
# Epoch 5/15
# 63/63 - 105s - loss: 0.7476 - accuracy: 0.6963 - val_loss: 0.8524 - val_accuracy: 0.6420
# Epoch 6/15
# 63/63 - 106s - loss: 0.6920 - accuracy: 0.7223 - val_loss: 0.8234 - val_accuracy: 0.6680
# Epoch 7/15
# 63/63 - 106s - loss: 0.6423 - accuracy: 0.7393 - val_loss: 0.7935 - val_accuracy: 0.6840
# Epoch 8/15
# 63/63 - 105s - loss: 0.6169 - accuracy: 0.7490 - val_loss: 0.7923 - val_accuracy: 0.6880
# Epoch 9/15
# 63/63 - 105s - loss: 0.5686 - accuracy: 0.7667 - val_loss: 0.7644 - val_accuracy: 0.6920
# Epoch 10/15
# 63/63 - 105s - loss: 0.5208 - accuracy: 0.7912 - val_loss: 0.7342 - val_accuracy: 0.7180
# Epoch 11/15
# 63/63 - 106s - loss: 0.5044 - accuracy: 0.8059 - val_loss: 0.7436 - val_accuracy: 0.7200
# Epoch 12/15
# 63/63 - 106s - loss: 0.4762 - accuracy: 0.8069 - val_loss: 0.7275 - val_accuracy: 0.7360
# Epoch 13/15
# 63/63 - 106s - loss: 0.4704 - accuracy: 0.8129 - val_loss: 0.7008 - val_accuracy: 0.7340
# Epoch 14/15
# 63/63 - 105s - loss: 0.4358 - accuracy: 0.8227 - val_loss: 0.6834 - val_accuracy: 0.7500
# Epoch 15/15
# 63/63 - 106s - loss: 0.3825 - accuracy: 0.8474 - val_loss: 0.6777 - val_accuracy: 0.7560
# 16/16 [==============================] - 3s 205ms/step - loss: 0.6777 - accuracy: 0.7560
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 4/Run-21\assets
# ---- Starting trial : run-22
# {'filter_size': 7, 'filters_number': 128, 'filter_size_2': 3, 'dense_size': 1024}
# Epoch 1/15
# 63/63 - 120s - loss: 1.6319 - accuracy: 0.4388 - val_loss: 1.1608 - val_accuracy: 0.4840
# Epoch 2/15
# 63/63 - 117s - loss: 0.9566 - accuracy: 0.5984 - val_loss: 0.9296 - val_accuracy: 0.6200
# Epoch 3/15
# 63/63 - 117s - loss: 0.8475 - accuracy: 0.6561 - val_loss: 0.8940 - val_accuracy: 0.6360
# Epoch 4/15
# 63/63 - 117s - loss: 0.7418 - accuracy: 0.6981 - val_loss: 0.8602 - val_accuracy: 0.6580
# Epoch 5/15
# 63/63 - 117s - loss: 0.6958 - accuracy: 0.7128 - val_loss: 0.7980 - val_accuracy: 0.6720
# Epoch 6/15
# 63/63 - 117s - loss: 0.6911 - accuracy: 0.7145 - val_loss: 0.8967 - val_accuracy: 0.6460
# Epoch 7/15
# 63/63 - 117s - loss: 0.6520 - accuracy: 0.7280 - val_loss: 0.7752 - val_accuracy: 0.6940
# Epoch 8/15
# 63/63 - 117s - loss: 0.5736 - accuracy: 0.7690 - val_loss: 0.7665 - val_accuracy: 0.6860
# Epoch 9/15
# 63/63 - 117s - loss: 0.5311 - accuracy: 0.7930 - val_loss: 0.8252 - val_accuracy: 0.6880
# Epoch 10/15
# 63/63 - 117s - loss: 0.5162 - accuracy: 0.7872 - val_loss: 0.7642 - val_accuracy: 0.6980
# Epoch 11/15
# 63/63 - 117s - loss: 0.4651 - accuracy: 0.8172 - val_loss: 0.7829 - val_accuracy: 0.7040
# Epoch 12/15
# 63/63 - 117s - loss: 0.4470 - accuracy: 0.8162 - val_loss: 0.7527 - val_accuracy: 0.7400
# Epoch 13/15
# 63/63 - 119s - loss: 0.4084 - accuracy: 0.8344 - val_loss: 0.6976 - val_accuracy: 0.7500
# Epoch 14/15
# 63/63 - 118s - loss: 0.3668 - accuracy: 0.8589 - val_loss: 0.7409 - val_accuracy: 0.7320
# Epoch 15/15
# 63/63 - 117s - loss: 0.3642 - accuracy: 0.8639 - val_loss: 0.8275 - val_accuracy: 0.7020
# 16/16 [==============================] - 4s 220ms/step - loss: 0.6976 - accuracy: 0.7500
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 4/Run-22\assets
# ---- Starting trial : run-23
# {'filter_size': 7, 'filters_number': 128, 'filter_size_2': 5, 'dense_size': 512}
# Epoch 1/15
# 63/63 - 157s - loss: 1.4200 - accuracy: 0.4505 - val_loss: 1.0949 - val_accuracy: 0.5480
# Epoch 2/15
# 63/63 - 154s - loss: 0.9589 - accuracy: 0.6074 - val_loss: 1.0003 - val_accuracy: 0.5700
# Epoch 3/15
# 63/63 - 153s - loss: 0.8733 - accuracy: 0.6416 - val_loss: 0.9382 - val_accuracy: 0.5860
# Epoch 4/15
# 63/63 - 154s - loss: 0.7703 - accuracy: 0.6851 - val_loss: 0.8776 - val_accuracy: 0.6440
# Epoch 5/15
# 63/63 - 154s - loss: 0.7325 - accuracy: 0.6938 - val_loss: 0.8109 - val_accuracy: 0.6620
# Epoch 6/15
# 63/63 - 155s - loss: 0.7124 - accuracy: 0.7195 - val_loss: 0.8362 - val_accuracy: 0.6600
# Epoch 7/15
# 63/63 - 153s - loss: 0.6952 - accuracy: 0.7218 - val_loss: 0.8314 - val_accuracy: 0.6680
# 16/16 [==============================] - 5s 294ms/step - loss: 0.8109 - accuracy: 0.6620
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 4/Run-23\assets
# ---- Starting trial : run-24
# {'filter_size': 7, 'filters_number': 128, 'filter_size_2': 5, 'dense_size': 1024}
# Epoch 1/15
# 63/63 - 168s - loss: 1.8450 - accuracy: 0.3859 - val_loss: 1.2663 - val_accuracy: 0.4500
# Epoch 2/15
# 63/63 - 169s - loss: 1.1086 - accuracy: 0.5152 - val_loss: 1.0512 - val_accuracy: 0.5580
# Epoch 3/15
# 63/63 - 176s - loss: 0.9533 - accuracy: 0.6021 - val_loss: 0.9764 - val_accuracy: 0.6080
# Epoch 4/15
# 63/63 - 176s - loss: 0.8467 - accuracy: 0.6486 - val_loss: 0.9606 - val_accuracy: 0.5800
# Epoch 5/15
# 63/63 - 175s - loss: 0.8232 - accuracy: 0.6558 - val_loss: 0.8897 - val_accuracy: 0.6480
# Epoch 6/15
# 63/63 - 177s - loss: 0.7537 - accuracy: 0.6831 - val_loss: 0.9382 - val_accuracy: 0.6020
# Epoch 7/15
# 63/63 - 179s - loss: 0.7488 - accuracy: 0.6818 - val_loss: 0.9108 - val_accuracy: 0.6200
# 16/16 [==============================] - 6s 344ms/step - loss: 0.8897 - accuracy: 0.6480
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 4/Run-24\assets

# %%
# Loading a model to evaluate on the test set
model = tf.keras.models.load_model(r"D:/sam/saved Models/Model 4/Run-3")

# %%
test_loss, test_accuracy = model.evaluate(test_images,test_labels)
# Out:
# 16/16 [==============================] - 2s 103ms/step - loss: 0.7253 - accuracy: 0.7580

# %%
# Printing the test results
print('Test loss: {0:.4f}. Test accuracy: {1:.2f}%'.format(test_loss, test_accuracy*100.))
# Out:
# Test loss: 0.7253. Test accuracy: 75.80%

# %%
# %load_ext tensorboard
# %tensorboard --logdir "D:/sam/Logs/Model 4/hparam_tuning"
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-8c8eb111577c0f42" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-8c8eb111577c0f42");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %load_ext tensorboard
# %tensorboard --logdir "D:/sam/Logs/Model 4/fit"
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 15704), started 0:01:25 ago. (Use '!kill 15704' to kill it.)
#       <iframe id="tensorboard-frame-86146703ba914400" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-86146703ba914400");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
