# %%
import io
import itertools

import numpy as np
import sklearn.metrics
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorboard.plugins.hparams import api as hp

# %%
#loading the data
train_data = np.load(r'datasets/Trousers & Jeans - Female - Train.npz')
val_data = np.load(r'datasets/Trousers & Jeans - Female - Validation.npz')
test_data = np.load(r'datasets/Trousers & Jeans - Female - Test.npz')

# %%
train_images, train_labels = train_data['images'], train_data['labels']
val_images, val_labels = val_data['images'], val_data['labels']
test_images, test_labels = test_data['images'], test_data['labels']

# %%
# scaling
train_images = train_images/255.
val_images = val_images/255.
test_images = test_images/255.

# %%
#constant definition
NUM_EPOCHS = 15
BATCH_SIZE = 64

# %%
#hyperparam definition
HP_FILTER_SIZE = hp.HParam('filter_size', hp.Discrete([5,7]))
HP_NUM_FILTER = hp.HParam('filters_number', hp.Discrete([64,96,128]))
# HP_FILTER_SIZE_2 = hp.HParam('filter_size_2', hp.Discrete([3,5]))
HP_DENSE_SIZE = hp.HParam('dense_size', hp.Discrete([512,1024]))

METRIC_ACCURACY = 'accuracy'

with tf.summary.create_file_writer(r'D:/sam/Logs/Model 6/hparam_tuning/').as_default():
    hp.hparams_config(
        hparams= [HP_FILTER_SIZE,HP_NUM_FILTER,HP_DENSE_SIZE],
        metrics = [hp.Metric(METRIC_ACCURACY,display_name='accuracy')]
    )

# %%
#model definition and training
def train_test_model(hparams,session_num):
    
    #model outline
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(hparams[HP_NUM_FILTER],hparams[HP_FILTER_SIZE], activation='relu', input_shape=(120,90,3)),
        tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
        tf.keras.layers.Conv2D(hparams[HP_NUM_FILTER],5,activation='relu'),
        tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(hparams[HP_DENSE_SIZE], activation='relu'),
        tf.keras.layers.Dense(4)
    ])
    
    
    loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
    
    model.compile(optimizer='adam', loss= loss_fn, metrics=['accuracy'])
    
    #defining the logging dir
    log_dir = 'D:/sam/Logs/Model 6/fit/'+'run-{}'.format(session_num)
    
    def plot_confusion_matrix(cm, class_names):
        figure = plt.figure(figsize=(12, 12))
        plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
        plt.title("Confusion matrix")
        plt.colorbar()
        tick_marks = np.arange(len(class_names))
        plt.xticks(tick_marks, class_names, rotation=45)
        plt.yticks(tick_marks, class_names)

        # Normalize the confusion matrix
        cm = np.around(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], decimals=2)

        # Use white text if squares are dark; otherwise black.
        threshold = cm.max() / 2.
        for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            color = "white" if cm[i, j] > threshold else "black"
            plt.text(j, i, cm[i, j], horizontalalignment="center", color=color)

        plt.tight_layout()
        plt.ylabel('True label')
        plt.xlabel('Predicted label') 
        return figure

    def plot_to_image(figure):
    
        #save the plot to a png in memory
        buf = io.BytesIO()
        plt.savefig(buf, format='png')
    
        #closing the figure to prevent from displaying in the notebook
        plt.close(figure)
    
        buf.seek(0)
    
        image = tf.image.decode_png(buf.getvalue(), channels=4)
    
        #add the batch dimension
        image = tf.expand_dims(image, 0)
    
        return image

    #file writer for logging cofusion matrix
    file_writer_cm = tf.summary.create_file_writer(log_dir + '/cm')
    
    def log_confusion_matrix(epoch, logs):
    #predict values for validation set
        test_pred_r = model.predict(val_images)
        test_pred = np.argmax(test_pred_r, axis=1)
    
        cm = sklearn.metrics.confusion_matrix(val_labels, test_pred)
    
        figure = plot_confusion_matrix(cm, class_names=['Jeans', 'Trousers'])
        cm_image = plot_to_image(figure)
    
        #log the confusion matrix as image summary
        with file_writer_cm.as_default():
            tf.summary.image('Confusion Matrix', cm_image, step=epoch)
            
    
    
    #defining callbacks
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir,histogram_freq = 1, profile_batch = 0)
    cm_callback = tf.keras.callbacks.LambdaCallback(on_epoch_end= log_confusion_matrix)
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        mode = 'auto',
        verbose=0,
        patience = 2,
        min_delta = 0,
        restore_best_weights= True
    )

    
    #training the model
    model.fit(
        train_images,
        train_labels,
        validation_data= (val_images,val_labels),
        verbose=2,
        epochs= NUM_EPOCHS,
        batch_size = BATCH_SIZE,
        callbacks=[tensorboard_callback,cm_callback,early_stopping]
        
    )
    
    #model performance evaluation
    _, accuracy = model.evaluate(val_images,val_labels)
    
    #saving the model
    model.save(r'D:/sam/saved Models/Model 6/Run-{}'.format(session_num))
    
    return accuracy

# %%
#logging the result function
def run(log_dir, hparams, session_num):
    
    with tf.summary.create_file_writer(log_dir).as_default():
        hp.hparams(hparams)  # record the values used in this trial
        accuracy = train_test_model(hparams, session_num)
        tf.summary.scalar(METRIC_ACCURACY, accuracy, step=1)

# %%
session_num = 1

for filter_size in HP_FILTER_SIZE.domain.values:
    for num_filter in HP_NUM_FILTER.domain.values:
#         for filter_size_2 in HP_FILTER_SIZE_2.domain.values:
            for dense_size in HP_DENSE_SIZE.domain.values:
        
                hparams = {
                    HP_FILTER_SIZE : filter_size,
                    HP_NUM_FILTER : num_filter,
                    HP_DENSE_SIZE: dense_size
                }
        
                run_name = 'run-%d' %session_num
                print('---- Starting trial : %s' % run_name)
                print({h.name: hparams[h] for h in hparams})
                run('D:/sam/Logs/Model 6/hparam_tuning/' +run_name, hparams, session_num)
        
                session_num += 1
# Out:
# ---- Starting trial : run-1
# {'filter_size': 5, 'filters_number': 64, 'dense_size': 512}
# Epoch 1/15
# 32/32 - 31s - loss: 0.9719 - accuracy: 0.5370 - val_loss: 0.6456 - val_accuracy: 0.5800
# Epoch 2/15
# 32/32 - 29s - loss: 0.6326 - accuracy: 0.6608 - val_loss: 0.5507 - val_accuracy: 0.7080
# Epoch 3/15
# 32/32 - 31s - loss: 0.5141 - accuracy: 0.7373 - val_loss: 0.4890 - val_accuracy: 0.7640
# Epoch 4/15
# 32/32 - 29s - loss: 0.4900 - accuracy: 0.7532 - val_loss: 0.5831 - val_accuracy: 0.7000
# Epoch 5/15
# 32/32 - 29s - loss: 0.4899 - accuracy: 0.7498 - val_loss: 0.5923 - val_accuracy: 0.7040
# 8/8 [==============================] - 1s 105ms/step - loss: 0.4890 - accuracy: 0.7640
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 6/Run-1\assets
# ---- Starting trial : run-2
# {'filter_size': 5, 'filters_number': 64, 'dense_size': 1024}
# Epoch 1/15
# 32/32 - 34s - loss: 1.4140 - accuracy: 0.6129 - val_loss: 0.8320 - val_accuracy: 0.5800
# Epoch 2/15
# 32/32 - 33s - loss: 0.5385 - accuracy: 0.7283 - val_loss: 0.4970 - val_accuracy: 0.7800
# Epoch 3/15
# 32/32 - 33s - loss: 0.5109 - accuracy: 0.7328 - val_loss: 0.5134 - val_accuracy: 0.7560
# Epoch 4/15
# 32/32 - 34s - loss: 0.4767 - accuracy: 0.7507 - val_loss: 0.5722 - val_accuracy: 0.6920
# 8/8 [==============================] - 1s 117ms/step - loss: 0.4970 - accuracy: 0.7800
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 6/Run-2\assets
# ---- Starting trial : run-3
# {'filter_size': 5, 'filters_number': 96, 'dense_size': 512}
# Epoch 1/15
# 32/32 - 52s - loss: 1.6286 - accuracy: 0.5205 - val_loss: 0.6494 - val_accuracy: 0.6280
# Epoch 2/15
# 32/32 - 48s - loss: 0.6023 - accuracy: 0.6953 - val_loss: 0.6542 - val_accuracy: 0.6320
# Epoch 3/15
# 32/32 - 48s - loss: 0.5703 - accuracy: 0.7118 - val_loss: 0.5755 - val_accuracy: 0.6880
# Epoch 4/15
# 32/32 - 48s - loss: 0.5233 - accuracy: 0.7438 - val_loss: 0.4930 - val_accuracy: 0.7400
# Epoch 5/15
# 32/32 - 49s - loss: 0.4582 - accuracy: 0.7662 - val_loss: 0.4891 - val_accuracy: 0.7880
# Epoch 6/15
# 32/32 - 48s - loss: 0.4472 - accuracy: 0.7797 - val_loss: 0.4861 - val_accuracy: 0.7760
# Epoch 7/15
# 32/32 - 48s - loss: 0.4805 - accuracy: 0.7637 - val_loss: 0.5910 - val_accuracy: 0.7360
# Epoch 8/15
# 32/32 - 48s - loss: 0.4350 - accuracy: 0.7797 - val_loss: 0.4615 - val_accuracy: 0.7960
# Epoch 9/15
# 32/32 - 48s - loss: 0.4052 - accuracy: 0.7852 - val_loss: 0.4559 - val_accuracy: 0.7840
# Epoch 10/15
# 32/32 - 48s - loss: 0.4180 - accuracy: 0.7872 - val_loss: 0.4539 - val_accuracy: 0.7880
# Epoch 11/15
# 32/32 - 49s - loss: 0.4093 - accuracy: 0.7957 - val_loss: 0.4421 - val_accuracy: 0.7640
# Epoch 12/15
# 32/32 - 48s - loss: 0.3873 - accuracy: 0.8027 - val_loss: 0.4429 - val_accuracy: 0.7720
# Epoch 13/15
# 32/32 - 48s - loss: 0.3483 - accuracy: 0.8397 - val_loss: 0.4463 - val_accuracy: 0.7600
# 8/8 [==============================] - 1s 178ms/step - loss: 0.4421 - accuracy: 0.7640
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 6/Run-3\assets
# ---- Starting trial : run-4
# {'filter_size': 5, 'filters_number': 96, 'dense_size': 1024}
# Epoch 1/15
# 32/32 - 55s - loss: 2.2622 - accuracy: 0.5245 - val_loss: 0.7279 - val_accuracy: 0.5280
# Epoch 2/15
# 32/32 - 52s - loss: 0.6616 - accuracy: 0.6309 - val_loss: 0.5812 - val_accuracy: 0.7200
# Epoch 3/15
# 32/32 - 53s - loss: 0.5341 - accuracy: 0.7338 - val_loss: 0.5277 - val_accuracy: 0.7520
# Epoch 4/15
# 32/32 - 52s - loss: 0.5001 - accuracy: 0.7383 - val_loss: 0.5213 - val_accuracy: 0.7480
# Epoch 5/15
# 32/32 - 52s - loss: 0.4744 - accuracy: 0.7587 - val_loss: 0.5006 - val_accuracy: 0.7640
# Epoch 6/15
# 32/32 - 52s - loss: 0.4896 - accuracy: 0.7532 - val_loss: 0.7470 - val_accuracy: 0.6160
# Epoch 7/15
# 32/32 - 52s - loss: 0.4834 - accuracy: 0.7592 - val_loss: 0.4864 - val_accuracy: 0.7400
# Epoch 8/15
# 32/32 - 52s - loss: 0.4728 - accuracy: 0.7752 - val_loss: 0.4838 - val_accuracy: 0.7560
# Epoch 9/15
# 32/32 - 54s - loss: 0.4615 - accuracy: 0.7797 - val_loss: 0.5673 - val_accuracy: 0.7240
# Epoch 10/15
# 32/32 - 52s - loss: 0.4628 - accuracy: 0.7677 - val_loss: 0.4828 - val_accuracy: 0.7600
# Epoch 11/15
# 32/32 - 52s - loss: 0.4302 - accuracy: 0.7837 - val_loss: 0.4903 - val_accuracy: 0.7680
# Epoch 12/15
# 32/32 - 52s - loss: 0.4226 - accuracy: 0.7882 - val_loss: 0.5361 - val_accuracy: 0.7280
# 8/8 [==============================] - 2s 197ms/step - loss: 0.4828 - accuracy: 0.7600
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 6/Run-4\assets
# ---- Starting trial : run-5
# {'filter_size': 5, 'filters_number': 128, 'dense_size': 512}
# Epoch 1/15
# 32/32 - 75s - loss: 1.7359 - accuracy: 0.5400 - val_loss: 0.6468 - val_accuracy: 0.6240
# Epoch 2/15
# 32/32 - 72s - loss: 0.5743 - accuracy: 0.7258 - val_loss: 0.5522 - val_accuracy: 0.7280
# Epoch 3/15
# 32/32 - 72s - loss: 0.5136 - accuracy: 0.7428 - val_loss: 0.5573 - val_accuracy: 0.6680
# Epoch 4/15
# 32/32 - 72s - loss: 0.4790 - accuracy: 0.7552 - val_loss: 0.5017 - val_accuracy: 0.7560
# Epoch 5/15
# 32/32 - 72s - loss: 0.4732 - accuracy: 0.7607 - val_loss: 0.4720 - val_accuracy: 0.7760
# Epoch 6/15
# 32/32 - 73s - loss: 0.4488 - accuracy: 0.7792 - val_loss: 0.4918 - val_accuracy: 0.7680
# Epoch 7/15
# 32/32 - 72s - loss: 0.4284 - accuracy: 0.7837 - val_loss: 0.4785 - val_accuracy: 0.7360
# 8/8 [==============================] - 2s 278ms/step - loss: 0.4720 - accuracy: 0.7760
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 6/Run-5\assets
# ---- Starting trial : run-6
# {'filter_size': 5, 'filters_number': 128, 'dense_size': 1024}
# Epoch 1/15
# 32/32 - 80s - loss: 2.6533 - accuracy: 0.5350 - val_loss: 0.6879 - val_accuracy: 0.5560
# Epoch 2/15
# 32/32 - 78s - loss: 0.6451 - accuracy: 0.6548 - val_loss: 0.8410 - val_accuracy: 0.5680
# Epoch 3/15
# 32/32 - 78s - loss: 0.5598 - accuracy: 0.7223 - val_loss: 0.5326 - val_accuracy: 0.7200
# Epoch 4/15
# 32/32 - 78s - loss: 0.4843 - accuracy: 0.7632 - val_loss: 0.5175 - val_accuracy: 0.7320
# Epoch 5/15
# 32/32 - 78s - loss: 0.4674 - accuracy: 0.7642 - val_loss: 0.5310 - val_accuracy: 0.7040
# Epoch 6/15
# 32/32 - 78s - loss: 0.4731 - accuracy: 0.7667 - val_loss: 0.5171 - val_accuracy: 0.6960
# Epoch 7/15
# 32/32 - 78s - loss: 0.4597 - accuracy: 0.7627 - val_loss: 0.5749 - val_accuracy: 0.7440
# Epoch 8/15
# 32/32 - 78s - loss: 0.4229 - accuracy: 0.7877 - val_loss: 0.4772 - val_accuracy: 0.7760
# Epoch 9/15
# 32/32 - 77s - loss: 0.4329 - accuracy: 0.7857 - val_loss: 0.4553 - val_accuracy: 0.7800
# Epoch 10/15
# 32/32 - 78s - loss: 0.4066 - accuracy: 0.8072 - val_loss: 0.5274 - val_accuracy: 0.7120
# Epoch 11/15
# 32/32 - 78s - loss: 0.4409 - accuracy: 0.7707 - val_loss: 0.5109 - val_accuracy: 0.7240
# 8/8 [==============================] - 2s 295ms/step - loss: 0.4553 - accuracy: 0.7800
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 6/Run-6\assets
# ---- Starting trial : run-7
# {'filter_size': 7, 'filters_number': 64, 'dense_size': 512}
# Epoch 1/15
# 32/32 - 32s - loss: 1.2429 - accuracy: 0.5235 - val_loss: 0.7566 - val_accuracy: 0.5280
# Epoch 2/15
# 32/32 - 32s - loss: 0.6225 - accuracy: 0.6563 - val_loss: 0.6035 - val_accuracy: 0.6720
# Epoch 3/15
# 32/32 - 31s - loss: 0.5602 - accuracy: 0.7023 - val_loss: 0.5513 - val_accuracy: 0.7320
# Epoch 4/15
# 32/32 - 31s - loss: 0.5247 - accuracy: 0.7273 - val_loss: 0.5094 - val_accuracy: 0.7680
# Epoch 5/15
# 32/32 - 31s - loss: 0.4933 - accuracy: 0.7562 - val_loss: 0.5045 - val_accuracy: 0.7560
# Epoch 6/15
# 32/32 - 31s - loss: 0.4608 - accuracy: 0.7727 - val_loss: 0.5219 - val_accuracy: 0.7120
# Epoch 7/15
# 32/32 - 31s - loss: 0.4594 - accuracy: 0.7657 - val_loss: 0.4868 - val_accuracy: 0.7600
# Epoch 8/15
# 32/32 - 32s - loss: 0.4623 - accuracy: 0.7627 - val_loss: 0.5173 - val_accuracy: 0.7400
# Epoch 9/15
# 32/32 - 31s - loss: 0.4885 - accuracy: 0.7433 - val_loss: 0.4937 - val_accuracy: 0.7240
# 8/8 [==============================] - 2s 217ms/step - loss: 0.4868 - accuracy: 0.7600
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 6/Run-7\assets
# ---- Starting trial : run-8
# {'filter_size': 7, 'filters_number': 64, 'dense_size': 1024}
# Epoch 1/15
# 32/32 - 37s - loss: 1.5437 - accuracy: 0.5475 - val_loss: 0.6309 - val_accuracy: 0.6320
# Epoch 2/15
# 32/32 - 34s - loss: 0.6222 - accuracy: 0.6833 - val_loss: 0.6069 - val_accuracy: 0.6600
# Epoch 3/15
# 32/32 - 34s - loss: 0.5494 - accuracy: 0.7118 - val_loss: 0.5842 - val_accuracy: 0.6920
# Epoch 4/15
# 32/32 - 34s - loss: 0.5331 - accuracy: 0.7293 - val_loss: 0.5825 - val_accuracy: 0.7240
# Epoch 5/15
# 32/32 - 34s - loss: 0.4844 - accuracy: 0.7557 - val_loss: 0.4953 - val_accuracy: 0.7520
# Epoch 6/15
# 32/32 - 35s - loss: 0.4486 - accuracy: 0.7802 - val_loss: 0.4833 - val_accuracy: 0.7600
# Epoch 7/15
# 32/32 - 36s - loss: 0.4522 - accuracy: 0.7712 - val_loss: 0.5154 - val_accuracy: 0.7000
# Epoch 8/15
# 32/32 - 34s - loss: 0.4319 - accuracy: 0.7782 - val_loss: 0.4628 - val_accuracy: 0.7640
# Epoch 9/15
# 32/32 - 37s - loss: 0.4532 - accuracy: 0.7672 - val_loss: 0.5211 - val_accuracy: 0.7120
# Epoch 10/15
# 32/32 - 35s - loss: 0.4363 - accuracy: 0.7772 - val_loss: 0.4630 - val_accuracy: 0.7840
# 8/8 [==============================] - 1s 122ms/step - loss: 0.4628 - accuracy: 0.7640
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 6/Run-8\assets
# ---- Starting trial : run-9
# {'filter_size': 7, 'filters_number': 96, 'dense_size': 512}
# Epoch 1/15
# 32/32 - 53s - loss: 1.4853 - accuracy: 0.5340 - val_loss: 0.6711 - val_accuracy: 0.6040
# Epoch 2/15
# 32/32 - 50s - loss: 0.6561 - accuracy: 0.6024 - val_loss: 0.5906 - val_accuracy: 0.6920
# Epoch 3/15
# 32/32 - 50s - loss: 0.5851 - accuracy: 0.6848 - val_loss: 0.5482 - val_accuracy: 0.7360
# Epoch 4/15
# 32/32 - 50s - loss: 0.5247 - accuracy: 0.7238 - val_loss: 0.5035 - val_accuracy: 0.7720
# Epoch 5/15
# 32/32 - 50s - loss: 0.4855 - accuracy: 0.7483 - val_loss: 0.5452 - val_accuracy: 0.7160
# Epoch 6/15
# 32/32 - 50s - loss: 0.4818 - accuracy: 0.7507 - val_loss: 0.5893 - val_accuracy: 0.7000
# 8/8 [==============================] - 2s 190ms/step - loss: 0.5035 - accuracy: 0.7720
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 6/Run-9\assets
# ---- Starting trial : run-10
# {'filter_size': 7, 'filters_number': 96, 'dense_size': 1024}
# Epoch 1/15
# 32/32 - 57s - loss: 1.4728 - accuracy: 0.5425 - val_loss: 0.6408 - val_accuracy: 0.6440
# Epoch 2/15
# 32/32 - 54s - loss: 0.5629 - accuracy: 0.7233 - val_loss: 0.6043 - val_accuracy: 0.6800
# Epoch 3/15
# 32/32 - 54s - loss: 0.5337 - accuracy: 0.7333 - val_loss: 0.5678 - val_accuracy: 0.7400
# Epoch 4/15
# 32/32 - 55s - loss: 0.5130 - accuracy: 0.7488 - val_loss: 0.5394 - val_accuracy: 0.7400
# Epoch 5/15
# 32/32 - 56s - loss: 0.4852 - accuracy: 0.7507 - val_loss: 0.7826 - val_accuracy: 0.6320
# Epoch 6/15
# 32/32 - 54s - loss: 0.4845 - accuracy: 0.7592 - val_loss: 0.4835 - val_accuracy: 0.7720
# Epoch 7/15
# 32/32 - 54s - loss: 0.4731 - accuracy: 0.7612 - val_loss: 0.5456 - val_accuracy: 0.7160
# Epoch 8/15
# 32/32 - 54s - loss: 0.4751 - accuracy: 0.7702 - val_loss: 0.4620 - val_accuracy: 0.7520
# Epoch 9/15
# 32/32 - 54s - loss: 0.4360 - accuracy: 0.7797 - val_loss: 0.4375 - val_accuracy: 0.7800
# Epoch 10/15
# 32/32 - 54s - loss: 0.4337 - accuracy: 0.7757 - val_loss: 0.4484 - val_accuracy: 0.7720
# Epoch 11/15
# 32/32 - 54s - loss: 0.4208 - accuracy: 0.7817 - val_loss: 0.4695 - val_accuracy: 0.7760
# 8/8 [==============================] - 2s 201ms/step - loss: 0.4375 - accuracy: 0.7800
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 6/Run-10\assets
# ---- Starting trial : run-11
# {'filter_size': 7, 'filters_number': 128, 'dense_size': 512}
# Epoch 1/15
# 32/32 - 77s - loss: 2.2102 - accuracy: 0.5689 - val_loss: 0.7032 - val_accuracy: 0.6280
# Epoch 2/15
# 32/32 - 75s - loss: 0.5692 - accuracy: 0.7168 - val_loss: 0.5472 - val_accuracy: 0.7160
# Epoch 3/15
# 32/32 - 74s - loss: 0.5219 - accuracy: 0.7363 - val_loss: 0.4971 - val_accuracy: 0.7480
# Epoch 4/15
# 32/32 - 74s - loss: 0.4770 - accuracy: 0.7542 - val_loss: 0.5389 - val_accuracy: 0.7160
# Epoch 5/15
# 32/32 - 74s - loss: 0.4590 - accuracy: 0.7702 - val_loss: 0.5014 - val_accuracy: 0.7800
# 8/8 [==============================] - 2s 286ms/step - loss: 0.4971 - accuracy: 0.7480
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 6/Run-11\assets
# ---- Starting trial : run-12
# {'filter_size': 7, 'filters_number': 128, 'dense_size': 1024}
# Epoch 1/15
# 32/32 - 83s - loss: 1.6940 - accuracy: 0.5095 - val_loss: 0.6664 - val_accuracy: 0.5720
# Epoch 2/15
# 32/32 - 79s - loss: 0.6373 - accuracy: 0.6299 - val_loss: 0.5649 - val_accuracy: 0.7320
# Epoch 3/15
# 32/32 - 80s - loss: 0.5578 - accuracy: 0.7103 - val_loss: 0.5957 - val_accuracy: 0.6760
# Epoch 4/15
# 32/32 - 81s - loss: 0.5723 - accuracy: 0.7123 - val_loss: 0.5765 - val_accuracy: 0.7120
# 8/8 [==============================] - 2s 301ms/step - loss: 0.5649 - accuracy: 0.7320
# INFO:tensorflow:Assets written to: D:/sam/saved Models/Model 6/Run-12\assets

# %%
# Loading a model to evaluate on the test set
model = tf.keras.models.load_model(r"D:/sam/saved Models/Model 6/Run-2")

# %%
test_loss, test_accuracy = model.evaluate(test_images,test_labels)
# Out:
# 8/8 [==============================] - 1s 112ms/step - loss: 0.4533 - accuracy: 0.8160

# %%
# Printing the test results
print('Test loss: {0:.4f}. Test accuracy: {1:.2f}%'.format(test_loss, test_accuracy*100.))
# Out:
# Test loss: 0.4533. Test accuracy: 81.60%

# %%
# %load_ext tensorboard
# %tensorboard --logdir "D:/sam/Logs/Model 6/hparam_tuning"
# Out:
#       <iframe id="tensorboard-frame-209dc53a581a3335" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-209dc53a581a3335");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %load_ext tensorboard
# %tensorboard --logdir "D:/sam/Logs/Model 6/fit"
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 14604), started 0:00:06 ago. (Use '!kill 14604' to kill it.)
#       <iframe id="tensorboard-frame-3251dcda4ffeb62f" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-3251dcda4ffeb62f");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
